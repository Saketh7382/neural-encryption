# %%
from random import seed
from random import random
from math import exp
import numpy as np
import pandas as pd
import textwrap
import timeit
import binascii
import json
import zlib, base64
import json
import io
import matplotlib.pyplot as plt
import time

# %%
# -*- coding: utf-8 -*-
import json

# Make it work for Python 2+3 and with Unicode
import io
try:
    to_unicode = unicode
except NameError:
    to_unicode = str

# %%
def addZeros(strr, n): 
    for i in range(n): 
        strr = "0" + strr 
    return strr 

def getXOR(a, b): 
    aLen = len(a) 
    bLen = len(b) 


    if (aLen > bLen): 
        b = addZeros(b, aLen - bLen) 
    elif (bLen > aLen): 
        a = addZeros(a, bLen - aLen) 
 
    lenn = max(aLen, bLen); 

    res = "" 
    for i in range(lenn): 
        if (a[i] == b[i]): 
            res += "0"
        else: 
            res += "1"
    return res

# %%
def text_to_bits(text, encoding='utf-8', errors='surrogatepass'):
    bits = bin(int(binascii.hexlify(text.encode(encoding, errors)), 16))[2:]
    return bits.zfill(8 * ((len(bits) + 7) // 8))

def text_from_bits(bits, encoding='utf-8', errors='surrogatepass'):
    n = int(bits, 2)
    return int2bytes(n).decode(encoding, errors)

def int2bytes(i):
    hex_string = '%x' % i
    n = len(hex_string)
    return binascii.unhexlify(hex_string.zfill(n + (n & 1)))

# %%
#initializing the network
def initialize_network(parameters):
    network = list()
    for j in range(1,len(parameters)):
        layer = [{'weights':[random() for i in range(parameters[j-1] + 1)]} for i in range(parameters[j])]
        network.append(layer)
    return network

# %%
# Make a prediction with a network
def predict(network, row, encr):
    outputs = forward_propagate(network, row, encr)
    k = [round(i) for i in outputs]
    if encr == 0:
        return k
    else:
        s = ""
        k = list(map(str,k))
        k = s.join(k)
        return k

# %%
# Calculate neuron activation for an input
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

# %%
# Transfer neuron activation
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
# Forward propagate input to a network output
def forward_propagate(network, row, getEncryption):
    count = 0
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        if count == 1 and getEncryption == 1:
            print("io")
            return new_inputs
        inputs = new_inputs
        count += 1
  
    return inputs

# %%
# Update network weights with error
def update_weights(network, row, l_rate):
    
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += l_rate * neuron['delta']

def train_network(network, train, l_rate, n_epoch, n_outputs, sno):
    count = 1
    y = []
    x = []
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            count += 1
            outputs = forward_propagate(network, row, 0)
            expected = row[-1]
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
        x.append(count)
        y.append(sum_error)
        if count % 100 == 0:
            print('> epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        count += 1
    f=open('../Test_images/decryptor_design_2bit_nw3.txt','a')
    s = "Epochs : " + str(n_epoch) +"\n"
    f.write(s)
    s = "Error : " + str(y[-1]) + "\n"
    f.write(s)
    f.close()
    plt.plot(x, y)
    plt.savefig('../Test_images/decryptor/2bit/nw3/decryptor_design_{}.png'.format(sno))
    plt.show()

# %%
# Calculate the derivative of an neuron output
def transfer_derivative(output):
    return output * (1.0 - output)

# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
    
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
# Transfer neuron activation
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
# Calculate neuron activation for an input
def activate(weights, inputs):
    #print(inputs)
    activation = weights[-1]
    for i in range(len(weights)-1):
        #print(i)
        #print(type(weights[i]))
        #print(type(inputs[i]))
        activation += weights[i] * inputs[i]
    return activation

# %%
#batch training
# Train a network for a fixed number of epochs
def train_network_batch(network, train, l_rate, n_epoch, n_outputs):
    count = 1
    k = 0
    batch = 2
    for i in range(batch):
        print('> Batch = %d' % (i+1))
        for epoch in range(n_epoch):
            sum_error = 0
            for row in train[k:k+10]:
                count += 1
                outputs = forward_propagate(network, row, 0)
                expected = row[-1]
                sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
                backward_propagate_error(network, expected)
                update_weights(network, row, l_rate)
            if count % 100 == 0:
                print('    epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
            count += 1
        k += 10

# %% [markdown]
# # Testing begins here for 8 bit output

# %%
# Read JSON file
with open('../datasets/languageDecryptor.json') as data_file:
    dataset = json.load(data_file)

# %%
layers_list = list()
for i in range(3):
    l = list()
    l.append([int(i) for i in input().split(" ")])
    l.append(float(input())/2)
    l.append(int(input())*10000)
    layers_list.append(l)
# Out:
# 8 18 18 8
# 2
# 1
# 8 18 18 8
# 1
# 1
# 8 18 18 8
# 0.5
# 1

# %%
count = 1
for i in layers_list:
    seed(1)
    network = initialize_network(i[0])
    n_inputs = len(dataset) - 1
    n_outputs = len(dataset[-1])
    f=open('../Test_images/decryptor_design_8bit.txt','a')
    s = "{})\n".format(c)
    f.write(s)
    s = "Test name : decryptor_{}_test\n".format(c)
    f.write(s)
    s = "Layers : " + str(i[0]) +"\n"
    f.write(s)
    f.close()
    start = timeit.default_timer()
    train_network(network, dataset, i[1], i[2], n_outputs, count)
    stop = timeit.default_timer()
    print("time = {}".format(stop - start))
    c = 0
    new_dataset = list()
    for b in dataset:
        k = predict(network,b,0)
        s = ""
        k = list(map(str,k))
        k = s.join(k)
        j = b[-1]
        s = ""
        j= list(map(str,j))
        j = s.join(j)
        if(k != j):
            new_dataset.append(b)
            c += 1
    f=open('../Test_images/decryptor_design_8bit.txt','a')
    s = "Decryption error : {} %\n".format(c)
    f.write(s)
    f.write("Time : {}".format(stop - start))
    f.close()
    print(str(c)+" %")
    count += 1
# Out:
# > epoch=99, lrate=1.000, error=190.436
# > epoch=199, lrate=1.000, error=153.861
# > epoch=299, lrate=1.000, error=73.989
# > epoch=399, lrate=1.000, error=38.778
# > epoch=499, lrate=1.000, error=25.761
# > epoch=599, lrate=1.000, error=20.136
# > epoch=699, lrate=1.000, error=23.726
# > epoch=799, lrate=1.000, error=14.885
# > epoch=899, lrate=1.000, error=13.180
# > epoch=999, lrate=1.000, error=12.747
# > epoch=1099, lrate=1.000, error=12.542
# > epoch=1199, lrate=1.000, error=12.431
# > epoch=1299, lrate=1.000, error=12.352
# > epoch=1399, lrate=1.000, error=12.296
# > epoch=1499, lrate=1.000, error=12.256
# > epoch=1599, lrate=1.000, error=12.225
# > epoch=1699, lrate=1.000, error=12.199
# > epoch=1799, lrate=1.000, error=12.176
# > epoch=1899, lrate=1.000, error=12.159
# > epoch=1999, lrate=1.000, error=12.144
# > epoch=2099, lrate=1.000, error=12.129
# > epoch=2199, lrate=1.000, error=25.882
# > epoch=2299, lrate=1.000, error=11.299
# > epoch=2399, lrate=1.000, error=10.307
# > epoch=2499, lrate=1.000, error=10.216
# > epoch=2599, lrate=1.000, error=10.171
# > epoch=2699, lrate=1.000, error=10.148
# > epoch=2799, lrate=1.000, error=10.132
# > epoch=2899, lrate=1.000, error=10.120
# > epoch=2999, lrate=1.000, error=10.111
# > epoch=3099, lrate=1.000, error=10.103
# > epoch=3199, lrate=1.000, error=10.096
# > epoch=3299, lrate=1.000, error=10.090
# > epoch=3399, lrate=1.000, error=10.085
# > epoch=3499, lrate=1.000, error=10.081
# > epoch=3599, lrate=1.000, error=10.077
# > epoch=3699, lrate=1.000, error=10.074
# > epoch=3799, lrate=1.000, error=10.071
# > epoch=3899, lrate=1.000, error=10.068
# > epoch=3999, lrate=1.000, error=10.065
# > epoch=4099, lrate=1.000, error=10.063
# > epoch=4199, lrate=1.000, error=10.061
# > epoch=4299, lrate=1.000, error=10.059
# > epoch=4399, lrate=1.000, error=10.057
# > epoch=4499, lrate=1.000, error=10.055
# > epoch=4599, lrate=1.000, error=10.054
# > epoch=4699, lrate=1.000, error=10.052
# > epoch=4799, lrate=1.000, error=10.051
# > epoch=4899, lrate=1.000, error=10.049
# > epoch=4999, lrate=1.000, error=10.048
# > epoch=5099, lrate=1.000, error=10.047
# > epoch=5199, lrate=1.000, error=10.046
# > epoch=5299, lrate=1.000, error=10.045
# > epoch=5399, lrate=1.000, error=10.044
# > epoch=5499, lrate=1.000, error=10.043
# > epoch=5599, lrate=1.000, error=10.042
# > epoch=5699, lrate=1.000, error=10.041
# > epoch=5799, lrate=1.000, error=10.040
# > epoch=5899, lrate=1.000, error=10.039
# > epoch=5999, lrate=1.000, error=10.039
# > epoch=6099, lrate=1.000, error=10.038
# > epoch=6199, lrate=1.000, error=10.037
# > epoch=6299, lrate=1.000, error=10.036
# > epoch=6399, lrate=1.000, error=10.036
# > epoch=6499, lrate=1.000, error=10.035
# > epoch=6599, lrate=1.000, error=10.035
# > epoch=6699, lrate=1.000, error=10.034
# > epoch=6799, lrate=1.000, error=10.033
# > epoch=6899, lrate=1.000, error=10.033
# > epoch=6999, lrate=1.000, error=10.032
# > epoch=7099, lrate=1.000, error=10.032
# > epoch=7199, lrate=1.000, error=10.031
# > epoch=7299, lrate=1.000, error=10.031
# > epoch=7399, lrate=1.000, error=10.030
# > epoch=7499, lrate=1.000, error=10.030
# > epoch=7599, lrate=1.000, error=10.029
# > epoch=7699, lrate=1.000, error=10.029
# > epoch=7799, lrate=1.000, error=10.029
# > epoch=7899, lrate=1.000, error=10.028
# > epoch=7999, lrate=1.000, error=10.028
# > epoch=8099, lrate=1.000, error=10.027
# > epoch=8199, lrate=1.000, error=10.027
# > epoch=8299, lrate=1.000, error=10.027
# > epoch=8399, lrate=1.000, error=10.026
# > epoch=8499, lrate=1.000, error=10.026
# > epoch=8599, lrate=1.000, error=10.026
# > epoch=8699, lrate=1.000, error=10.025
# > epoch=8799, lrate=1.000, error=10.025
# > epoch=8899, lrate=1.000, error=10.025
# > epoch=8999, lrate=1.000, error=10.024
# > epoch=9099, lrate=1.000, error=10.024
# > epoch=9199, lrate=1.000, error=10.024
# > epoch=9299, lrate=1.000, error=10.023
# > epoch=9399, lrate=1.000, error=10.023
# > epoch=9499, lrate=1.000, error=10.023
# > epoch=9599, lrate=1.000, error=10.023
# > epoch=9699, lrate=1.000, error=10.022
# > epoch=9799, lrate=1.000, error=10.022
# > epoch=9899, lrate=1.000, error=10.022
# > epoch=9999, lrate=1.000, error=10.022
# time = 314.6388895130003
# 9 %
# > epoch=99, lrate=0.500, error=223.557
# > epoch=199, lrate=0.500, error=174.314
# > epoch=299, lrate=0.500, error=158.024
# > epoch=399, lrate=0.500, error=92.825
# > epoch=499, lrate=0.500, error=46.072
# > epoch=599, lrate=0.500, error=17.516
# > epoch=699, lrate=0.500, error=13.383
# > epoch=799, lrate=0.500, error=11.074
# > epoch=899, lrate=0.500, error=9.811
# > epoch=999, lrate=0.500, error=9.603
# > epoch=1099, lrate=0.500, error=9.480
# > epoch=1199, lrate=0.500, error=9.396
# > epoch=1299, lrate=0.500, error=9.282
# > epoch=1399, lrate=0.500, error=8.300
# > epoch=1499, lrate=0.500, error=7.283
# > epoch=1599, lrate=0.500, error=7.227
# > epoch=1699, lrate=0.500, error=7.198
# > epoch=1799, lrate=0.500, error=7.178
# > epoch=1899, lrate=0.500, error=7.162
# > epoch=1999, lrate=0.500, error=7.149
# > epoch=2099, lrate=0.500, error=7.139
# > epoch=2199, lrate=0.500, error=7.130
# > epoch=2299, lrate=0.500, error=7.122
# > epoch=2399, lrate=0.500, error=7.115
# > epoch=2499, lrate=0.500, error=7.109
# > epoch=2599, lrate=0.500, error=7.104
# > epoch=2699, lrate=0.500, error=7.099
# > epoch=2799, lrate=0.500, error=7.094
# > epoch=2899, lrate=0.500, error=7.090
# > epoch=2999, lrate=0.500, error=7.086
# > epoch=3099, lrate=0.500, error=7.083
# > epoch=3199, lrate=0.500, error=7.080
# > epoch=3299, lrate=0.500, error=7.077
# > epoch=3399, lrate=0.500, error=7.074
# > epoch=3499, lrate=0.500, error=7.072
# > epoch=3599, lrate=0.500, error=7.069
# > epoch=3699, lrate=0.500, error=7.067
# > epoch=3799, lrate=0.500, error=7.065
# > epoch=3899, lrate=0.500, error=7.063
# > epoch=3999, lrate=0.500, error=7.061
# > epoch=4099, lrate=0.500, error=7.059
# > epoch=4199, lrate=0.500, error=7.058
# > epoch=4299, lrate=0.500, error=7.056
# > epoch=4399, lrate=0.500, error=7.055
# > epoch=4499, lrate=0.500, error=7.053
# > epoch=4599, lrate=0.500, error=7.052
# > epoch=4699, lrate=0.500, error=7.051
# > epoch=4799, lrate=0.500, error=7.049
# > epoch=4899, lrate=0.500, error=7.048
# > epoch=4999, lrate=0.500, error=7.047
# > epoch=5099, lrate=0.500, error=7.046
# > epoch=5199, lrate=0.500, error=7.045
# > epoch=5299, lrate=0.500, error=7.044
# > epoch=5399, lrate=0.500, error=7.043
# > epoch=5499, lrate=0.500, error=7.042
# > epoch=5599, lrate=0.500, error=7.041
# > epoch=5699, lrate=0.500, error=7.041
# > epoch=5799, lrate=0.500, error=7.040
# > epoch=5899, lrate=0.500, error=7.039
# > epoch=5999, lrate=0.500, error=7.038
# > epoch=6099, lrate=0.500, error=7.038
# > epoch=6199, lrate=0.500, error=7.037
# > epoch=6299, lrate=0.500, error=7.036
# > epoch=6399, lrate=0.500, error=7.036
# > epoch=6499, lrate=0.500, error=7.035
# > epoch=6599, lrate=0.500, error=7.034
# > epoch=6699, lrate=0.500, error=7.034
# > epoch=6799, lrate=0.500, error=7.033
# > epoch=6899, lrate=0.500, error=7.033
# > epoch=6999, lrate=0.500, error=7.032
# > epoch=7099, lrate=0.500, error=7.032
# > epoch=7199, lrate=0.500, error=7.031
# > epoch=7299, lrate=0.500, error=7.031
# > epoch=7399, lrate=0.500, error=7.030
# > epoch=7499, lrate=0.500, error=7.030
# > epoch=7599, lrate=0.500, error=7.029
# > epoch=7699, lrate=0.500, error=7.029
# > epoch=7799, lrate=0.500, error=7.028
# > epoch=7899, lrate=0.500, error=7.028
# > epoch=7999, lrate=0.500, error=7.028
# > epoch=8099, lrate=0.500, error=7.027
# > epoch=8199, lrate=0.500, error=7.027
# > epoch=8299, lrate=0.500, error=7.026
# > epoch=8399, lrate=0.500, error=7.026
# > epoch=8499, lrate=0.500, error=7.026
# > epoch=8599, lrate=0.500, error=7.025
# > epoch=8699, lrate=0.500, error=7.025
# > epoch=8799, lrate=0.500, error=7.025
# > epoch=8899, lrate=0.500, error=7.024
# > epoch=8999, lrate=0.500, error=7.024
# > epoch=9099, lrate=0.500, error=7.024
# > epoch=9199, lrate=0.500, error=7.023
# > epoch=9299, lrate=0.500, error=7.023
# > epoch=9399, lrate=0.500, error=7.022
# > epoch=9499, lrate=0.500, error=7.022
# > epoch=9599, lrate=0.500, error=7.021
# > epoch=9699, lrate=0.500, error=7.019
# > epoch=9799, lrate=0.500, error=6.769
# > epoch=9899, lrate=0.500, error=6.078
# > epoch=9999, lrate=0.500, error=6.060
# time = 314.13428868100164
# 6 %
# > epoch=99, lrate=0.250, error=235.702
# > epoch=199, lrate=0.250, error=213.212
# > epoch=299, lrate=0.250, error=191.482
# > epoch=399, lrate=0.250, error=190.503
# > epoch=499, lrate=0.250, error=184.571
# > epoch=599, lrate=0.250, error=152.488
# > epoch=699, lrate=0.250, error=132.271
# > epoch=799, lrate=0.250, error=107.478
# > epoch=899, lrate=0.250, error=82.526
# > epoch=999, lrate=0.250, error=63.250
# > epoch=1099, lrate=0.250, error=48.046
# > epoch=1199, lrate=0.250, error=41.691
# > epoch=1299, lrate=0.250, error=35.327
# > epoch=1399, lrate=0.250, error=27.591
# > epoch=1499, lrate=0.250, error=24.061
# > epoch=1599, lrate=0.250, error=29.605
# > epoch=1699, lrate=0.250, error=19.853
# > epoch=1799, lrate=0.250, error=19.429
# > epoch=1899, lrate=0.250, error=18.381
# > epoch=1999, lrate=0.250, error=17.434
# > epoch=2099, lrate=0.250, error=17.119
# > epoch=2199, lrate=0.250, error=16.935
# > epoch=2299, lrate=0.250, error=16.803
# > epoch=2399, lrate=0.250, error=15.820
# > epoch=2499, lrate=0.250, error=15.688
# > epoch=2599, lrate=0.250, error=15.609
# > epoch=2699, lrate=0.250, error=15.550
# > epoch=2799, lrate=0.250, error=15.503
# > epoch=2899, lrate=0.250, error=15.463
# > epoch=2999, lrate=0.250, error=15.430
# > epoch=3099, lrate=0.250, error=15.401
# > epoch=3199, lrate=0.250, error=15.375
# > epoch=3299, lrate=0.250, error=15.353
# > epoch=3399, lrate=0.250, error=15.332
# > epoch=3499, lrate=0.250, error=15.313
# > epoch=3599, lrate=0.250, error=15.295
# > epoch=3699, lrate=0.250, error=15.278
# > epoch=3799, lrate=0.250, error=15.261
# > epoch=3899, lrate=0.250, error=15.245
# > epoch=3999, lrate=0.250, error=15.229
# > epoch=4099, lrate=0.250, error=15.209
# > epoch=4199, lrate=0.250, error=14.600
# > epoch=4299, lrate=0.250, error=14.402
# > epoch=4399, lrate=0.250, error=14.339
# > epoch=4499, lrate=0.250, error=14.301
# > epoch=4599, lrate=0.250, error=14.274
# > epoch=4699, lrate=0.250, error=14.253
# > epoch=4799, lrate=0.250, error=14.235
# > epoch=4899, lrate=0.250, error=14.220
# > epoch=4999, lrate=0.250, error=14.205
# > epoch=5099, lrate=0.250, error=14.164
# > epoch=5199, lrate=0.250, error=13.268
# > epoch=5299, lrate=0.250, error=13.236
# > epoch=5399, lrate=0.250, error=13.216
# > epoch=5499, lrate=0.250, error=13.201
# > epoch=5599, lrate=0.250, error=13.189
# > epoch=5699, lrate=0.250, error=13.179
# > epoch=5799, lrate=0.250, error=13.170
# > epoch=5899, lrate=0.250, error=13.163
# > epoch=5999, lrate=0.250, error=13.156
# > epoch=6099, lrate=0.250, error=13.149
# > epoch=6199, lrate=0.250, error=24.399
# > epoch=6299, lrate=0.250, error=13.173
# > epoch=6399, lrate=0.250, error=13.133
# > epoch=6499, lrate=0.250, error=13.190
# > epoch=6599, lrate=0.250, error=12.193
# > epoch=6699, lrate=0.250, error=12.145
# > epoch=6799, lrate=0.250, error=12.116
# > epoch=6899, lrate=0.250, error=11.285
# > epoch=6999, lrate=0.250, error=11.202
# > epoch=7099, lrate=0.250, error=11.173
# > epoch=7199, lrate=0.250, error=11.155
# > epoch=7299, lrate=0.250, error=11.143
# > epoch=7399, lrate=0.250, error=11.134
# > epoch=7499, lrate=0.250, error=11.125
# > epoch=7599, lrate=0.250, error=11.074
# > epoch=7699, lrate=0.250, error=10.282
# > epoch=7799, lrate=0.250, error=10.219
# > epoch=7899, lrate=0.250, error=10.192
# > epoch=7999, lrate=0.250, error=10.176
# > epoch=8099, lrate=0.250, error=10.164
# > epoch=8199, lrate=0.250, error=10.155
# > epoch=8299, lrate=0.250, error=10.147
# > epoch=8399, lrate=0.250, error=10.141
# > epoch=8499, lrate=0.250, error=10.135
# > epoch=8599, lrate=0.250, error=10.130
# > epoch=8699, lrate=0.250, error=10.125
# > epoch=8799, lrate=0.250, error=10.121
# > epoch=8899, lrate=0.250, error=10.117
# > epoch=8999, lrate=0.250, error=10.114
# > epoch=9099, lrate=0.250, error=10.111
# > epoch=9199, lrate=0.250, error=10.108
# > epoch=9299, lrate=0.250, error=10.105
# > epoch=9399, lrate=0.250, error=10.102
# > epoch=9499, lrate=0.250, error=10.100
# > epoch=9599, lrate=0.250, error=10.097
# > epoch=9699, lrate=0.250, error=10.095
# > epoch=9799, lrate=0.250, error=10.093
# > epoch=9899, lrate=0.250, error=10.091
# > epoch=9999, lrate=0.250, error=10.089
# time = 312.92091386700486
# 10 %

# %% [markdown]
# # Testing begins here for 4 bit output

# %%
with open('../datasets/languageDecryptor.json') as data_file:
    temp1 = json.load(data_file)

# %%
for i in range(100):
    temp1[i][-1] = temp1[i][-1][:4]

# %%
layers_list = list()
for i in range(8):
    l = list()
    l.append([int(i) for i in input().split(" ")])
    l.append(float(input())/2)
    l.append(int(input())*10000)
    layers_list.append(l)
# Out:
# 8 18 18 4
# 1
# 1
# 8 18 16 4
# 1
# 1
# 8 16 8 4
# 1
# 1
# 8 16 8 4
# 2
# 1
# 8 16 4
# 1
# 1
# 8 8 4
# 1
# 1
# 8 12 4
# 1
# 1
# 8 15 4
# 1
# 1

# %%
count = 1
for i in layers_list:
    seed(1)
    network = initialize_network(i[0])
    n_inputs = len(temp1) - 1
    n_outputs = len(temp1[-1])
    f=open('../Test_images/decryptor_design_4bit.txt','a')
    s = "{})\n".format(c)
    f.write(s)
    s = "Test name : decryptor_{}_test\n".format(count)
    f.write(s)
    s = "Layers : " + str(i[0]) +"\n"
    f.write(s)
    f.close()
    start = timeit.default_timer()
    train_network(network, temp1, i[1], i[2], n_outputs, count)
    stop = timeit.default_timer()
    print("time = {}".format(stop - start))
    c = 0
    new_dataset = list()
    for b in dataset:
        k = predict(network,b,0)
        s = ""
        k = list(map(str,k))
        k = s.join(k)
        j = b[-1]
        s = ""
        j= list(map(str,j))
        j = s.join(j)
        if(k != j):
            new_dataset.append(b)
            c += 1
    f=open('../Test_images/decryptor_design_4bit.txt','a')
    f.write("Time : {}".format(stop - start))
    f.close()
    print(str(c)+" %")
    count += 1
# Out:
# > epoch=99, lrate=0.500, error=69.025
# > epoch=199, lrate=0.500, error=69.022
# > epoch=299, lrate=0.500, error=69.088
# > epoch=399, lrate=0.500, error=69.339
# > epoch=499, lrate=0.500, error=47.144
# > epoch=599, lrate=0.500, error=46.767
# > epoch=699, lrate=0.500, error=44.365
# > epoch=799, lrate=0.500, error=45.760
# > epoch=899, lrate=0.500, error=46.402
# > epoch=999, lrate=0.500, error=47.143
# > epoch=1099, lrate=0.500, error=46.457
# > epoch=1199, lrate=0.500, error=44.284
# > epoch=1299, lrate=0.500, error=43.486
# > epoch=1399, lrate=0.500, error=34.780
# > epoch=1499, lrate=0.500, error=27.819
# > epoch=1599, lrate=0.500, error=19.647
# > epoch=1699, lrate=0.500, error=14.817
# > epoch=1799, lrate=0.500, error=12.407
# > epoch=1899, lrate=0.500, error=8.763
# > epoch=1999, lrate=0.500, error=8.304
# > epoch=2099, lrate=0.500, error=8.221
# > epoch=2199, lrate=0.500, error=8.173
# > epoch=2299, lrate=0.500, error=8.142
# > epoch=2399, lrate=0.500, error=8.119
# > epoch=2499, lrate=0.500, error=8.103
# > epoch=2599, lrate=0.500, error=8.091
# > epoch=2699, lrate=0.500, error=8.081
# > epoch=2799, lrate=0.500, error=8.073
# > epoch=2899, lrate=0.500, error=8.067
# > epoch=2999, lrate=0.500, error=8.061
# > epoch=3099, lrate=0.500, error=8.057
# > epoch=3199, lrate=0.500, error=8.053
# > epoch=3299, lrate=0.500, error=8.049
# > epoch=3399, lrate=0.500, error=8.046
# > epoch=3499, lrate=0.500, error=8.043
# > epoch=3599, lrate=0.500, error=8.041
# > epoch=3699, lrate=0.500, error=8.039
# > epoch=3799, lrate=0.500, error=8.037
# > epoch=3899, lrate=0.500, error=8.035
# > epoch=3999, lrate=0.500, error=8.033
# > epoch=4099, lrate=0.500, error=8.031
# > epoch=4199, lrate=0.500, error=8.025
# > epoch=4299, lrate=0.500, error=7.118
# > epoch=4399, lrate=0.500, error=7.062
# > epoch=4499, lrate=0.500, error=7.050
# > epoch=4599, lrate=0.500, error=7.043
# > epoch=4699, lrate=0.500, error=7.039
# > epoch=4799, lrate=0.500, error=7.035
# > epoch=4899, lrate=0.500, error=7.033
# > epoch=4999, lrate=0.500, error=7.030
# > epoch=5099, lrate=0.500, error=7.029
# > epoch=5199, lrate=0.500, error=7.027
# > epoch=5299, lrate=0.500, error=7.026
# > epoch=5399, lrate=0.500, error=7.024
# > epoch=5499, lrate=0.500, error=7.023
# > epoch=5599, lrate=0.500, error=7.022
# > epoch=5699, lrate=0.500, error=7.021
# > epoch=5799, lrate=0.500, error=7.021
# > epoch=5899, lrate=0.500, error=7.020
# > epoch=5999, lrate=0.500, error=7.019
# > epoch=6099, lrate=0.500, error=7.019
# > epoch=6199, lrate=0.500, error=7.018
# > epoch=6299, lrate=0.500, error=7.017
# > epoch=6399, lrate=0.500, error=7.017
# > epoch=6499, lrate=0.500, error=7.016
# > epoch=6599, lrate=0.500, error=7.016
# > epoch=6699, lrate=0.500, error=7.016
# > epoch=6799, lrate=0.500, error=7.015
# > epoch=6899, lrate=0.500, error=7.015
# > epoch=6999, lrate=0.500, error=7.014
# > epoch=7099, lrate=0.500, error=7.014
# > epoch=7199, lrate=0.500, error=7.014
# > epoch=7299, lrate=0.500, error=7.013
# > epoch=7399, lrate=0.500, error=7.013
# > epoch=7499, lrate=0.500, error=7.013
# > epoch=7599, lrate=0.500, error=7.013
# > epoch=7699, lrate=0.500, error=7.012
# > epoch=7799, lrate=0.500, error=7.012
# > epoch=7899, lrate=0.500, error=7.012
# > epoch=7999, lrate=0.500, error=7.012
# > epoch=8099, lrate=0.500, error=7.011
# > epoch=8199, lrate=0.500, error=7.011
# > epoch=8299, lrate=0.500, error=7.011
# > epoch=8399, lrate=0.500, error=7.011
# > epoch=8499, lrate=0.500, error=7.010
# > epoch=8599, lrate=0.500, error=7.010
# > epoch=8699, lrate=0.500, error=7.010
# > epoch=8799, lrate=0.500, error=7.010
# > epoch=8899, lrate=0.500, error=7.010
# > epoch=8999, lrate=0.500, error=7.010
# > epoch=9099, lrate=0.500, error=7.009
# > epoch=9199, lrate=0.500, error=7.009
# > epoch=9299, lrate=0.500, error=7.009
# > epoch=9399, lrate=0.500, error=7.009
# > epoch=9499, lrate=0.500, error=7.005
# > epoch=9599, lrate=0.500, error=7.025
# > epoch=9699, lrate=0.500, error=7.018
# > epoch=9799, lrate=0.500, error=7.015
# > epoch=9899, lrate=0.500, error=7.014
# > epoch=9999, lrate=0.500, error=7.012
# time = 273.68293932000233
# 100 %
# > epoch=99, lrate=0.500, error=47.783
# > epoch=199, lrate=0.500, error=47.785
# > epoch=299, lrate=0.500, error=48.314
# > epoch=399, lrate=0.500, error=48.813
# > epoch=499, lrate=0.500, error=47.845
# > epoch=599, lrate=0.500, error=47.538
# > epoch=699, lrate=0.500, error=47.255
# > epoch=799, lrate=0.500, error=47.495
# > epoch=899, lrate=0.500, error=45.088
# > epoch=999, lrate=0.500, error=31.218
# > epoch=1099, lrate=0.500, error=22.167
# > epoch=1199, lrate=0.500, error=12.862
# > epoch=1299, lrate=0.500, error=6.799
# > epoch=1399, lrate=0.500, error=5.187
# > epoch=1499, lrate=0.500, error=4.208
# > epoch=1599, lrate=0.500, error=4.056
# > epoch=1699, lrate=0.500, error=3.986
# > epoch=1799, lrate=0.500, error=3.881
# > epoch=1899, lrate=0.500, error=3.343
# > epoch=1999, lrate=0.500, error=3.202
# > epoch=2099, lrate=0.500, error=3.151
# > epoch=2199, lrate=0.500, error=3.121
# > epoch=2299, lrate=0.500, error=3.102
# > epoch=2399, lrate=0.500, error=3.087
# > epoch=2499, lrate=0.500, error=3.076
# > epoch=2599, lrate=0.500, error=3.068
# > epoch=2699, lrate=0.500, error=3.061
# > epoch=2799, lrate=0.500, error=3.055
# > epoch=2899, lrate=0.500, error=3.051
# > epoch=2999, lrate=0.500, error=3.047
# > epoch=3099, lrate=0.500, error=3.043
# > epoch=3199, lrate=0.500, error=3.040
# > epoch=3299, lrate=0.500, error=3.038
# > epoch=3399, lrate=0.500, error=3.035
# > epoch=3499, lrate=0.500, error=3.033
# > epoch=3599, lrate=0.500, error=3.031
# > epoch=3699, lrate=0.500, error=3.030
# > epoch=3799, lrate=0.500, error=3.028
# > epoch=3899, lrate=0.500, error=3.025
# > epoch=3999, lrate=0.500, error=2.099
# > epoch=4099, lrate=0.500, error=2.053
# > epoch=4199, lrate=0.500, error=2.041
# > epoch=4299, lrate=0.500, error=2.035
# > epoch=4399, lrate=0.500, error=2.031
# > epoch=4499, lrate=0.500, error=2.028
# > epoch=4599, lrate=0.500, error=2.026
# > epoch=4699, lrate=0.500, error=2.024
# > epoch=4799, lrate=0.500, error=2.022
# > epoch=4899, lrate=0.500, error=2.021
# > epoch=4999, lrate=0.500, error=2.020
# > epoch=5099, lrate=0.500, error=2.019
# > epoch=5199, lrate=0.500, error=2.018
# > epoch=5299, lrate=0.500, error=2.017
# > epoch=5399, lrate=0.500, error=2.016
# > epoch=5499, lrate=0.500, error=2.016
# > epoch=5599, lrate=0.500, error=2.015
# > epoch=5699, lrate=0.500, error=2.015
# > epoch=5799, lrate=0.500, error=2.014
# > epoch=5899, lrate=0.500, error=2.014
# > epoch=5999, lrate=0.500, error=2.013
# > epoch=6099, lrate=0.500, error=2.013
# > epoch=6199, lrate=0.500, error=2.013
# > epoch=6299, lrate=0.500, error=2.012
# > epoch=6399, lrate=0.500, error=2.012
# > epoch=6499, lrate=0.500, error=2.012
# > epoch=6599, lrate=0.500, error=2.011
# > epoch=6699, lrate=0.500, error=2.011
# > epoch=6799, lrate=0.500, error=2.011
# > epoch=6899, lrate=0.500, error=2.010
# > epoch=6999, lrate=0.500, error=2.010
# > epoch=7099, lrate=0.500, error=2.010
# > epoch=7199, lrate=0.500, error=2.010
# > epoch=7299, lrate=0.500, error=2.010
# > epoch=7399, lrate=0.500, error=2.009
# > epoch=7499, lrate=0.500, error=2.009
# > epoch=7599, lrate=0.500, error=2.009
# > epoch=7699, lrate=0.500, error=2.009
# > epoch=7799, lrate=0.500, error=2.009
# > epoch=7899, lrate=0.500, error=2.008
# > epoch=7999, lrate=0.500, error=2.008
# > epoch=8099, lrate=0.500, error=2.008
# > epoch=8199, lrate=0.500, error=2.008
# > epoch=8299, lrate=0.500, error=2.008
# > epoch=8399, lrate=0.500, error=2.008
# > epoch=8499, lrate=0.500, error=2.008
# > epoch=8599, lrate=0.500, error=2.008
# > epoch=8699, lrate=0.500, error=2.007
# > epoch=8799, lrate=0.500, error=2.007
# > epoch=8899, lrate=0.500, error=2.007
# > epoch=8999, lrate=0.500, error=2.007
# > epoch=9099, lrate=0.500, error=2.007
# > epoch=9199, lrate=0.500, error=2.007
# > epoch=9299, lrate=0.500, error=2.007
# > epoch=9399, lrate=0.500, error=2.007
# > epoch=9499, lrate=0.500, error=2.007
# > epoch=9599, lrate=0.500, error=2.006
# > epoch=9699, lrate=0.500, error=2.006
# > epoch=9799, lrate=0.500, error=2.006
# > epoch=9899, lrate=0.500, error=2.006
# > epoch=9999, lrate=0.500, error=2.006
# time = 255.5854870289986
# 100 %
# > epoch=99, lrate=0.500, error=54.217
# > epoch=199, lrate=0.500, error=54.220
# > epoch=299, lrate=0.500, error=55.236
# > epoch=399, lrate=0.500, error=58.599
# > epoch=499, lrate=0.500, error=52.611
# > epoch=599, lrate=0.500, error=40.069
# > epoch=699, lrate=0.500, error=20.771
# > epoch=799, lrate=0.500, error=11.402
# > epoch=899, lrate=0.500, error=7.008
# > epoch=999, lrate=0.500, error=4.637
# > epoch=1099, lrate=0.500, error=2.771
# > epoch=1199, lrate=0.500, error=2.328
# > epoch=1299, lrate=0.500, error=2.225
# > epoch=1399, lrate=0.500, error=2.170
# > epoch=1499, lrate=0.500, error=2.137
# > epoch=1599, lrate=0.500, error=2.115
# > epoch=1699, lrate=0.500, error=2.099
# > epoch=1799, lrate=0.500, error=2.087
# > epoch=1899, lrate=0.500, error=2.077
# > epoch=1999, lrate=0.500, error=2.070
# > epoch=2099, lrate=0.500, error=2.064
# > epoch=2199, lrate=0.500, error=2.058
# > epoch=2299, lrate=0.500, error=2.054
# > epoch=2399, lrate=0.500, error=2.050
# > epoch=2499, lrate=0.500, error=2.047
# > epoch=2599, lrate=0.500, error=2.044
# > epoch=2699, lrate=0.500, error=2.041
# > epoch=2799, lrate=0.500, error=2.039
# > epoch=2899, lrate=0.500, error=2.037
# > epoch=2999, lrate=0.500, error=2.035
# > epoch=3099, lrate=0.500, error=2.033
# > epoch=3199, lrate=0.500, error=2.032
# > epoch=3299, lrate=0.500, error=2.030
# > epoch=3399, lrate=0.500, error=2.029
# > epoch=3499, lrate=0.500, error=2.028
# > epoch=3599, lrate=0.500, error=2.027
# > epoch=3699, lrate=0.500, error=2.026
# > epoch=3799, lrate=0.500, error=2.025
# > epoch=3899, lrate=0.500, error=2.024
# > epoch=3999, lrate=0.500, error=2.023
# > epoch=4099, lrate=0.500, error=2.023
# > epoch=4199, lrate=0.500, error=2.022
# > epoch=4299, lrate=0.500, error=2.021
# > epoch=4399, lrate=0.500, error=2.021
# > epoch=4499, lrate=0.500, error=2.020
# > epoch=4599, lrate=0.500, error=2.019
# > epoch=4699, lrate=0.500, error=2.019
# > epoch=4799, lrate=0.500, error=2.018
# > epoch=4899, lrate=0.500, error=2.018
# > epoch=4999, lrate=0.500, error=2.017
# > epoch=5099, lrate=0.500, error=2.017
# > epoch=5199, lrate=0.500, error=2.017
# > epoch=5299, lrate=0.500, error=2.016
# > epoch=5399, lrate=0.500, error=2.016
# > epoch=5499, lrate=0.500, error=2.016
# > epoch=5599, lrate=0.500, error=2.015
# > epoch=5699, lrate=0.500, error=2.015
# > epoch=5799, lrate=0.500, error=2.015
# > epoch=5899, lrate=0.500, error=2.014
# > epoch=5999, lrate=0.500, error=2.014
# > epoch=6099, lrate=0.500, error=2.014
# > epoch=6199, lrate=0.500, error=2.013
# > epoch=6299, lrate=0.500, error=2.013
# > epoch=6399, lrate=0.500, error=2.013
# > epoch=6499, lrate=0.500, error=2.013
# > epoch=6599, lrate=0.500, error=2.012
# > epoch=6699, lrate=0.500, error=2.012
# > epoch=6799, lrate=0.500, error=2.012
# > epoch=6899, lrate=0.500, error=2.012
# > epoch=6999, lrate=0.500, error=2.012
# > epoch=7099, lrate=0.500, error=2.011
# > epoch=7199, lrate=0.500, error=2.011
# > epoch=7299, lrate=0.500, error=2.011
# > epoch=7399, lrate=0.500, error=2.011
# > epoch=7499, lrate=0.500, error=2.011
# > epoch=7599, lrate=0.500, error=2.011
# > epoch=7699, lrate=0.500, error=2.010
# > epoch=7799, lrate=0.500, error=2.010
# > epoch=7899, lrate=0.500, error=2.010
# > epoch=7999, lrate=0.500, error=2.010
# > epoch=8099, lrate=0.500, error=2.010
# > epoch=8199, lrate=0.500, error=2.010
# > epoch=8299, lrate=0.500, error=2.010
# > epoch=8399, lrate=0.500, error=2.009
# > epoch=8499, lrate=0.500, error=2.009
# > epoch=8599, lrate=0.500, error=2.009
# > epoch=8699, lrate=0.500, error=2.009
# > epoch=8799, lrate=0.500, error=2.009
# > epoch=8899, lrate=0.500, error=2.009
# > epoch=8999, lrate=0.500, error=2.009
# > epoch=9099, lrate=0.500, error=2.009
# > epoch=9199, lrate=0.500, error=2.008
# > epoch=9299, lrate=0.500, error=2.008
# > epoch=9399, lrate=0.500, error=2.008
# > epoch=9499, lrate=0.500, error=2.008
# > epoch=9599, lrate=0.500, error=2.008
# > epoch=9699, lrate=0.500, error=2.008
# > epoch=9799, lrate=0.500, error=2.008
# > epoch=9899, lrate=0.500, error=2.008
# > epoch=9999, lrate=0.500, error=2.008
# time = 162.64616498300165
# 100 %
# > epoch=99, lrate=1.000, error=47.258
# > epoch=199, lrate=1.000, error=49.660
# > epoch=299, lrate=1.000, error=50.044
# > epoch=399, lrate=1.000, error=48.037
# > epoch=499, lrate=1.000, error=25.898
# > epoch=599, lrate=1.000, error=10.537
# > epoch=699, lrate=1.000, error=6.049
# > epoch=799, lrate=1.000, error=5.334
# > epoch=899, lrate=1.000, error=5.203
# > epoch=999, lrate=1.000, error=5.134
# > epoch=1099, lrate=1.000, error=4.160
# > epoch=1199, lrate=1.000, error=4.110
# > epoch=1299, lrate=1.000, error=4.087
# > epoch=1399, lrate=1.000, error=4.073
# > epoch=1499, lrate=1.000, error=4.063
# > epoch=1599, lrate=1.000, error=4.055
# > epoch=1699, lrate=1.000, error=4.050
# > epoch=1799, lrate=1.000, error=4.045
# > epoch=1899, lrate=1.000, error=4.041
# > epoch=1999, lrate=1.000, error=4.038
# > epoch=2099, lrate=1.000, error=4.035
# > epoch=2199, lrate=1.000, error=4.033
# > epoch=2299, lrate=1.000, error=4.031
# > epoch=2399, lrate=1.000, error=4.029
# > epoch=2499, lrate=1.000, error=4.028
# > epoch=2599, lrate=1.000, error=4.026
# > epoch=2699, lrate=1.000, error=4.025
# > epoch=2799, lrate=1.000, error=4.024
# > epoch=2899, lrate=1.000, error=4.023
# > epoch=2999, lrate=1.000, error=4.022
# > epoch=3099, lrate=1.000, error=4.021
# > epoch=3199, lrate=1.000, error=4.020
# > epoch=3299, lrate=1.000, error=4.019
# > epoch=3399, lrate=1.000, error=4.019
# > epoch=3499, lrate=1.000, error=4.018
# > epoch=3599, lrate=1.000, error=4.017
# > epoch=3699, lrate=1.000, error=4.017
# > epoch=3799, lrate=1.000, error=4.016
# > epoch=3899, lrate=1.000, error=4.016
# > epoch=3999, lrate=1.000, error=4.015
# > epoch=4099, lrate=1.000, error=4.015
# > epoch=4199, lrate=1.000, error=4.015
# > epoch=4299, lrate=1.000, error=4.014
# > epoch=4399, lrate=1.000, error=4.014
# > epoch=4499, lrate=1.000, error=4.013
# > epoch=4599, lrate=1.000, error=4.013
# > epoch=4699, lrate=1.000, error=4.013
# > epoch=4799, lrate=1.000, error=4.012
# > epoch=4899, lrate=1.000, error=4.012
# > epoch=4999, lrate=1.000, error=4.012
# > epoch=5099, lrate=1.000, error=4.012
# > epoch=5199, lrate=1.000, error=4.011
# > epoch=5299, lrate=1.000, error=4.011
# > epoch=5399, lrate=1.000, error=4.011
# > epoch=5499, lrate=1.000, error=4.011
# > epoch=5599, lrate=1.000, error=4.010
# > epoch=5699, lrate=1.000, error=4.010
# > epoch=5799, lrate=1.000, error=4.010
# > epoch=5899, lrate=1.000, error=4.010
# > epoch=5999, lrate=1.000, error=4.010
# > epoch=6099, lrate=1.000, error=4.010
# > epoch=6199, lrate=1.000, error=4.009
# > epoch=6299, lrate=1.000, error=4.009
# > epoch=6399, lrate=1.000, error=4.009
# > epoch=6499, lrate=1.000, error=4.009
# > epoch=6599, lrate=1.000, error=4.009
# > epoch=6699, lrate=1.000, error=4.009
# > epoch=6799, lrate=1.000, error=4.008
# > epoch=6899, lrate=1.000, error=4.008
# > epoch=6999, lrate=1.000, error=4.008
# > epoch=7099, lrate=1.000, error=4.008
# > epoch=7199, lrate=1.000, error=4.008
# > epoch=7299, lrate=1.000, error=4.008
# > epoch=7399, lrate=1.000, error=4.008
# > epoch=7499, lrate=1.000, error=4.008
# > epoch=7599, lrate=1.000, error=4.007
# > epoch=7699, lrate=1.000, error=4.007
# > epoch=7799, lrate=1.000, error=4.007
# > epoch=7899, lrate=1.000, error=4.007
# > epoch=7999, lrate=1.000, error=4.007
# > epoch=8099, lrate=1.000, error=4.007
# > epoch=8199, lrate=1.000, error=4.007
# > epoch=8299, lrate=1.000, error=4.007
# > epoch=8399, lrate=1.000, error=4.007
# > epoch=8499, lrate=1.000, error=4.007
# > epoch=8599, lrate=1.000, error=4.007
# > epoch=8699, lrate=1.000, error=4.006
# > epoch=8799, lrate=1.000, error=4.006
# > epoch=8899, lrate=1.000, error=4.006
# > epoch=8999, lrate=1.000, error=4.006
# > epoch=9099, lrate=1.000, error=4.006
# > epoch=9199, lrate=1.000, error=4.006
# > epoch=9299, lrate=1.000, error=4.006
# > epoch=9399, lrate=1.000, error=4.006
# > epoch=9499, lrate=1.000, error=4.006
# > epoch=9599, lrate=1.000, error=4.006
# > epoch=9699, lrate=1.000, error=4.006
# > epoch=9799, lrate=1.000, error=4.006
# > epoch=9899, lrate=1.000, error=4.006
# > epoch=9999, lrate=1.000, error=4.006
# time = 162.21587865900074
# 100 %
# > epoch=99, lrate=0.500, error=49.069
# > epoch=199, lrate=0.500, error=26.766
# > epoch=299, lrate=0.500, error=13.591
# > epoch=399, lrate=0.500, error=7.657
# > epoch=499, lrate=0.500, error=4.677
# > epoch=599, lrate=0.500, error=3.951
# > epoch=699, lrate=0.500, error=3.068
# > epoch=799, lrate=0.500, error=2.707
# > epoch=899, lrate=0.500, error=2.539
# > epoch=999, lrate=0.500, error=2.435
# > epoch=1099, lrate=0.500, error=2.365
# > epoch=1199, lrate=0.500, error=2.314
# > epoch=1299, lrate=0.500, error=2.275
# > epoch=1399, lrate=0.500, error=2.244
# > epoch=1499, lrate=0.500, error=2.220
# > epoch=1599, lrate=0.500, error=2.199
# > epoch=1699, lrate=0.500, error=2.183
# > epoch=1799, lrate=0.500, error=2.168
# > epoch=1899, lrate=0.500, error=2.156
# > epoch=1999, lrate=0.500, error=2.145
# > epoch=2099, lrate=0.500, error=2.136
# > epoch=2199, lrate=0.500, error=2.128
# > epoch=2299, lrate=0.500, error=2.120
# > epoch=2399, lrate=0.500, error=2.114
# > epoch=2499, lrate=0.500, error=2.108
# > epoch=2599, lrate=0.500, error=2.103
# > epoch=2699, lrate=0.500, error=2.098
# > epoch=2799, lrate=0.500, error=2.094
# > epoch=2899, lrate=0.500, error=2.090
# > epoch=2999, lrate=0.500, error=2.086
# > epoch=3099, lrate=0.500, error=2.082
# > epoch=3199, lrate=0.500, error=2.079
# > epoch=3299, lrate=0.500, error=2.076
# > epoch=3399, lrate=0.500, error=2.074
# > epoch=3499, lrate=0.500, error=2.071
# > epoch=3599, lrate=0.500, error=2.069
# > epoch=3699, lrate=0.500, error=2.067
# > epoch=3799, lrate=0.500, error=2.064
# > epoch=3899, lrate=0.500, error=2.062
# > epoch=3999, lrate=0.500, error=2.061
# > epoch=4099, lrate=0.500, error=2.059
# > epoch=4199, lrate=0.500, error=2.057
# > epoch=4299, lrate=0.500, error=2.056
# > epoch=4399, lrate=0.500, error=2.054
# > epoch=4499, lrate=0.500, error=2.053
# > epoch=4599, lrate=0.500, error=2.052
# > epoch=4699, lrate=0.500, error=2.050
# > epoch=4799, lrate=0.500, error=2.049
# > epoch=4899, lrate=0.500, error=2.048
# > epoch=4999, lrate=0.500, error=2.047
# > epoch=5099, lrate=0.500, error=2.046
# > epoch=5199, lrate=0.500, error=2.045
# > epoch=5299, lrate=0.500, error=2.044
# > epoch=5399, lrate=0.500, error=2.043
# > epoch=5499, lrate=0.500, error=2.042
# > epoch=5599, lrate=0.500, error=2.041
# > epoch=5699, lrate=0.500, error=2.040
# > epoch=5799, lrate=0.500, error=2.040
# > epoch=5899, lrate=0.500, error=2.039
# > epoch=5999, lrate=0.500, error=2.038
# > epoch=6099, lrate=0.500, error=2.037
# > epoch=6199, lrate=0.500, error=2.037
# > epoch=6299, lrate=0.500, error=2.036
# > epoch=6399, lrate=0.500, error=2.035
# > epoch=6499, lrate=0.500, error=2.035
# > epoch=6599, lrate=0.500, error=2.034
# > epoch=6699, lrate=0.500, error=2.034
# > epoch=6799, lrate=0.500, error=2.033
# > epoch=6899, lrate=0.500, error=2.033
# > epoch=6999, lrate=0.500, error=2.032
# > epoch=7099, lrate=0.500, error=2.032
# > epoch=7199, lrate=0.500, error=2.031
# > epoch=7299, lrate=0.500, error=2.031
# > epoch=7399, lrate=0.500, error=2.030
# > epoch=7499, lrate=0.500, error=2.030
# > epoch=7599, lrate=0.500, error=2.029
# > epoch=7699, lrate=0.500, error=2.029
# > epoch=7799, lrate=0.500, error=2.028
# > epoch=7899, lrate=0.500, error=2.028
# > epoch=7999, lrate=0.500, error=2.028
# > epoch=8099, lrate=0.500, error=2.027
# > epoch=8199, lrate=0.500, error=2.027
# > epoch=8299, lrate=0.500, error=2.027
# > epoch=8399, lrate=0.500, error=2.026
# > epoch=8499, lrate=0.500, error=2.026
# > epoch=8599, lrate=0.500, error=2.026
# > epoch=8699, lrate=0.500, error=2.025
# > epoch=8799, lrate=0.500, error=2.025
# > epoch=8899, lrate=0.500, error=2.025
# > epoch=8999, lrate=0.500, error=2.024
# > epoch=9099, lrate=0.500, error=2.024
# > epoch=9199, lrate=0.500, error=2.024
# > epoch=9299, lrate=0.500, error=2.023
# > epoch=9399, lrate=0.500, error=2.023
# > epoch=9499, lrate=0.500, error=2.023
# > epoch=9599, lrate=0.500, error=2.023
# > epoch=9699, lrate=0.500, error=2.022
# > epoch=9799, lrate=0.500, error=2.022
# > epoch=9899, lrate=0.500, error=2.022
# > epoch=9999, lrate=0.500, error=2.022
# time = 109.79633064399968
# 100 %
# > epoch=99, lrate=0.500, error=48.197
# > epoch=199, lrate=0.500, error=38.993
# > epoch=299, lrate=0.500, error=32.114
# > epoch=399, lrate=0.500, error=27.889
# > epoch=499, lrate=0.500, error=25.422
# > epoch=599, lrate=0.500, error=23.752
# > epoch=699, lrate=0.500, error=21.721
# > epoch=799, lrate=0.500, error=20.736
# > epoch=899, lrate=0.500, error=19.063
# > epoch=999, lrate=0.500, error=18.025
# > epoch=1099, lrate=0.500, error=17.410
# > epoch=1199, lrate=0.500, error=17.036
# > epoch=1299, lrate=0.500, error=16.547
# > epoch=1399, lrate=0.500, error=16.210
# > epoch=1499, lrate=0.500, error=15.860
# > epoch=1599, lrate=0.500, error=15.621
# > epoch=1699, lrate=0.500, error=15.596
# > epoch=1799, lrate=0.500, error=15.250
# > epoch=1899, lrate=0.500, error=15.196
# > epoch=1999, lrate=0.500, error=15.157
# > epoch=2099, lrate=0.500, error=14.930
# > epoch=2199, lrate=0.500, error=15.364
# > epoch=2299, lrate=0.500, error=15.273
# > epoch=2399, lrate=0.500, error=15.210
# > epoch=2499, lrate=0.500, error=18.184
# > epoch=2599, lrate=0.500, error=14.888
# > epoch=2699, lrate=0.500, error=15.875
# > epoch=2799, lrate=0.500, error=14.887
# > epoch=2899, lrate=0.500, error=14.508
# > epoch=2999, lrate=0.500, error=14.469
# > epoch=3099, lrate=0.500, error=14.906
# > epoch=3199, lrate=0.500, error=14.334
# > epoch=3299, lrate=0.500, error=14.269
# > epoch=3399, lrate=0.500, error=14.420
# > epoch=3499, lrate=0.500, error=15.443
# > epoch=3599, lrate=0.500, error=14.033
# > epoch=3699, lrate=0.500, error=14.241
# > epoch=3799, lrate=0.500, error=14.319
# > epoch=3899, lrate=0.500, error=14.045
# > epoch=3999, lrate=0.500, error=14.665
# > epoch=4099, lrate=0.500, error=14.007
# > epoch=4199, lrate=0.500, error=14.059
# > epoch=4299, lrate=0.500, error=15.629
# > epoch=4399, lrate=0.500, error=16.696
# > epoch=4499, lrate=0.500, error=14.561
# > epoch=4599, lrate=0.500, error=13.815
# > epoch=4699, lrate=0.500, error=14.174
# > epoch=4799, lrate=0.500, error=15.453
# > epoch=4899, lrate=0.500, error=13.756
# > epoch=4999, lrate=0.500, error=13.793
# > epoch=5099, lrate=0.500, error=14.111
# > epoch=5199, lrate=0.500, error=16.173
# > epoch=5299, lrate=0.500, error=13.740
# > epoch=5399, lrate=0.500, error=16.267
# > epoch=5499, lrate=0.500, error=13.707
# > epoch=5599, lrate=0.500, error=13.735
# > epoch=5699, lrate=0.500, error=13.743
# > epoch=5799, lrate=0.500, error=13.660
# > epoch=5899, lrate=0.500, error=13.663
# > epoch=5999, lrate=0.500, error=13.643
# > epoch=6099, lrate=0.500, error=13.660
# > epoch=6199, lrate=0.500, error=13.629
# > epoch=6299, lrate=0.500, error=13.808
# > epoch=6399, lrate=0.500, error=13.584
# > epoch=6499, lrate=0.500, error=13.590
# > epoch=6599, lrate=0.500, error=13.592
# > epoch=6699, lrate=0.500, error=13.588
# > epoch=6799, lrate=0.500, error=13.747
# > epoch=6899, lrate=0.500, error=15.635
# > epoch=6999, lrate=0.500, error=17.037
# > epoch=7099, lrate=0.500, error=13.647
# > epoch=7199, lrate=0.500, error=13.554
# > epoch=7299, lrate=0.500, error=14.145
# > epoch=7399, lrate=0.500, error=13.733
# > epoch=7499, lrate=0.500, error=13.551
# > epoch=7599, lrate=0.500, error=13.701
# > epoch=7699, lrate=0.500, error=13.610
# > epoch=7799, lrate=0.500, error=15.560
# > epoch=7899, lrate=0.500, error=14.735
# > epoch=7999, lrate=0.500, error=13.498
# > epoch=8099, lrate=0.500, error=13.514
# > epoch=8199, lrate=0.500, error=13.625
# > epoch=8299, lrate=0.500, error=14.085
# > epoch=8399, lrate=0.500, error=13.588
# > epoch=8499, lrate=0.500, error=13.577
# > epoch=8599, lrate=0.500, error=13.463
# > epoch=8699, lrate=0.500, error=16.394
# > epoch=8799, lrate=0.500, error=13.728
# > epoch=8899, lrate=0.500, error=13.880
# > epoch=8999, lrate=0.500, error=13.445
# > epoch=9099, lrate=0.500, error=14.456
# > epoch=9199, lrate=0.500, error=13.499
# > epoch=9299, lrate=0.500, error=13.462
# > epoch=9399, lrate=0.500, error=13.732
# > epoch=9499, lrate=0.500, error=13.462
# > epoch=9599, lrate=0.500, error=13.419
# > epoch=9699, lrate=0.500, error=14.306
# > epoch=9799, lrate=0.500, error=14.101
# > epoch=9899, lrate=0.500, error=13.482
# > epoch=9999, lrate=0.500, error=13.421
# time = 67.04625746600504
# 100 %
# > epoch=99, lrate=0.500, error=46.990
# > epoch=199, lrate=0.500, error=29.238
# > epoch=299, lrate=0.500, error=21.779
# > epoch=399, lrate=0.500, error=17.764
# > epoch=499, lrate=0.500, error=14.759
# > epoch=599, lrate=0.500, error=12.632
# > epoch=699, lrate=0.500, error=11.537
# > epoch=799, lrate=0.500, error=11.081
# > epoch=899, lrate=0.500, error=10.825
# > epoch=999, lrate=0.500, error=9.846
# > epoch=1099, lrate=0.500, error=9.650
# > epoch=1199, lrate=0.500, error=9.540
# > epoch=1299, lrate=0.500, error=9.464
# > epoch=1399, lrate=0.500, error=9.406
# > epoch=1499, lrate=0.500, error=9.361
# > epoch=1599, lrate=0.500, error=9.325
# > epoch=1699, lrate=0.500, error=9.295
# > epoch=1799, lrate=0.500, error=9.271
# > epoch=1899, lrate=0.500, error=9.250
# > epoch=1999, lrate=0.500, error=9.232
# > epoch=2099, lrate=0.500, error=9.216
# > epoch=2199, lrate=0.500, error=9.202
# > epoch=2299, lrate=0.500, error=9.190
# > epoch=2399, lrate=0.500, error=9.179
# > epoch=2499, lrate=0.500, error=9.169
# > epoch=2599, lrate=0.500, error=9.161
# > epoch=2699, lrate=0.500, error=9.152
# > epoch=2799, lrate=0.500, error=9.145
# > epoch=2899, lrate=0.500, error=9.138
# > epoch=2999, lrate=0.500, error=9.132
# > epoch=3099, lrate=0.500, error=9.126
# > epoch=3199, lrate=0.500, error=9.120
# > epoch=3299, lrate=0.500, error=9.115
# > epoch=3399, lrate=0.500, error=9.110
# > epoch=3499, lrate=0.500, error=9.106
# > epoch=3599, lrate=0.500, error=9.102
# > epoch=3699, lrate=0.500, error=9.098
# > epoch=3799, lrate=0.500, error=9.094
# > epoch=3899, lrate=0.500, error=9.091
# > epoch=3999, lrate=0.500, error=9.087
# > epoch=4099, lrate=0.500, error=9.084
# > epoch=4199, lrate=0.500, error=9.082
# > epoch=4299, lrate=0.500, error=9.079
# > epoch=4399, lrate=0.500, error=9.076
# > epoch=4499, lrate=0.500, error=9.074
# > epoch=4599, lrate=0.500, error=9.072
# > epoch=4699, lrate=0.500, error=9.070
# > epoch=4799, lrate=0.500, error=9.068
# > epoch=4899, lrate=0.500, error=9.066
# > epoch=4999, lrate=0.500, error=9.064
# > epoch=5099, lrate=0.500, error=9.063
# > epoch=5199, lrate=0.500, error=9.061
# > epoch=5299, lrate=0.500, error=9.060
# > epoch=5399, lrate=0.500, error=9.058
# > epoch=5499, lrate=0.500, error=9.057
# > epoch=5599, lrate=0.500, error=9.055
# > epoch=5699, lrate=0.500, error=9.054
# > epoch=5799, lrate=0.500, error=9.053
# > epoch=5899, lrate=0.500, error=9.052
# > epoch=5999, lrate=0.500, error=9.051
# > epoch=6099, lrate=0.500, error=9.050
# > epoch=6199, lrate=0.500, error=9.049
# > epoch=6299, lrate=0.500, error=9.048
# > epoch=6399, lrate=0.500, error=9.047
# > epoch=6499, lrate=0.500, error=9.046
# > epoch=6599, lrate=0.500, error=9.045
# > epoch=6699, lrate=0.500, error=9.044
# > epoch=6799, lrate=0.500, error=9.043
# > epoch=6899, lrate=0.500, error=9.042
# > epoch=6999, lrate=0.500, error=9.042
# > epoch=7099, lrate=0.500, error=9.041
# > epoch=7199, lrate=0.500, error=9.040
# > epoch=7299, lrate=0.500, error=9.039
# > epoch=7399, lrate=0.500, error=9.039
# > epoch=7499, lrate=0.500, error=9.038
# > epoch=7599, lrate=0.500, error=9.037
# > epoch=7699, lrate=0.500, error=9.037
# > epoch=7799, lrate=0.500, error=9.036
# > epoch=7899, lrate=0.500, error=9.036
# > epoch=7999, lrate=0.500, error=9.035
# > epoch=8099, lrate=0.500, error=9.035
# > epoch=8199, lrate=0.500, error=9.034
# > epoch=8299, lrate=0.500, error=9.034
# > epoch=8399, lrate=0.500, error=9.033
# > epoch=8499, lrate=0.500, error=9.033
# > epoch=8599, lrate=0.500, error=9.032
# > epoch=8699, lrate=0.500, error=9.032
# > epoch=8799, lrate=0.500, error=9.031
# > epoch=8899, lrate=0.500, error=9.031
# > epoch=8999, lrate=0.500, error=9.030
# > epoch=9099, lrate=0.500, error=9.030
# > epoch=9199, lrate=0.500, error=9.029
# > epoch=9299, lrate=0.500, error=9.029
# > epoch=9399, lrate=0.500, error=9.029
# > epoch=9499, lrate=0.500, error=9.028
# > epoch=9599, lrate=0.500, error=9.028
# > epoch=9699, lrate=0.500, error=9.027
# > epoch=9799, lrate=0.500, error=9.027
# > epoch=9899, lrate=0.500, error=8.045
# > epoch=9999, lrate=0.500, error=8.036
# time = 87.85233807599434
# 100 %
# > epoch=99, lrate=0.500, error=45.186
# > epoch=199, lrate=0.500, error=24.524
# > epoch=299, lrate=0.500, error=14.114
# > epoch=399, lrate=0.500, error=9.225
# > epoch=499, lrate=0.500, error=7.478
# > epoch=599, lrate=0.500, error=6.951
# > epoch=699, lrate=0.500, error=6.702
# > epoch=799, lrate=0.500, error=6.557
# > epoch=899, lrate=0.500, error=6.461
# > epoch=999, lrate=0.500, error=6.394
# > epoch=1099, lrate=0.500, error=6.343
# > epoch=1199, lrate=0.500, error=6.305
# > epoch=1299, lrate=0.500, error=6.274
# > epoch=1399, lrate=0.500, error=6.249
# > epoch=1499, lrate=0.500, error=6.228
# > epoch=1599, lrate=0.500, error=6.211
# > epoch=1699, lrate=0.500, error=6.196
# > epoch=1799, lrate=0.500, error=6.183
# > epoch=1899, lrate=0.500, error=6.171
# > epoch=1999, lrate=0.500, error=6.161
# > epoch=2099, lrate=0.500, error=6.152
# > epoch=2199, lrate=0.500, error=6.144
# > epoch=2299, lrate=0.500, error=6.137
# > epoch=2399, lrate=0.500, error=6.130
# > epoch=2499, lrate=0.500, error=6.124
# > epoch=2599, lrate=0.500, error=6.119
# > epoch=2699, lrate=0.500, error=6.114
# > epoch=2799, lrate=0.500, error=6.109
# > epoch=2899, lrate=0.500, error=6.105
# > epoch=2999, lrate=0.500, error=6.101
# > epoch=3099, lrate=0.500, error=6.098
# > epoch=3199, lrate=0.500, error=6.094
# > epoch=3299, lrate=0.500, error=6.091
# > epoch=3399, lrate=0.500, error=6.088
# > epoch=3499, lrate=0.500, error=6.085
# > epoch=3599, lrate=0.500, error=6.082
# > epoch=3699, lrate=0.500, error=6.080
# > epoch=3799, lrate=0.500, error=6.078
# > epoch=3899, lrate=0.500, error=6.075
# > epoch=3999, lrate=0.500, error=6.073
# > epoch=4099, lrate=0.500, error=6.071
# > epoch=4199, lrate=0.500, error=6.069
# > epoch=4299, lrate=0.500, error=6.068
# > epoch=4399, lrate=0.500, error=6.066
# > epoch=4499, lrate=0.500, error=6.064
# > epoch=4599, lrate=0.500, error=6.063
# > epoch=4699, lrate=0.500, error=6.061
# > epoch=4799, lrate=0.500, error=6.060
# > epoch=4899, lrate=0.500, error=6.059
# > epoch=4999, lrate=0.500, error=6.057
# > epoch=5099, lrate=0.500, error=6.056
# > epoch=5199, lrate=0.500, error=6.055
# > epoch=5299, lrate=0.500, error=6.054
# > epoch=5399, lrate=0.500, error=6.053
# > epoch=5499, lrate=0.500, error=6.051
# > epoch=5599, lrate=0.500, error=6.050
# > epoch=5699, lrate=0.500, error=6.049
# > epoch=5799, lrate=0.500, error=6.049
# > epoch=5899, lrate=0.500, error=6.048
# > epoch=5999, lrate=0.500, error=6.047
# > epoch=6099, lrate=0.500, error=6.046
# > epoch=6199, lrate=0.500, error=6.045
# > epoch=6299, lrate=0.500, error=6.044
# > epoch=6399, lrate=0.500, error=6.043
# > epoch=6499, lrate=0.500, error=6.043
# > epoch=6599, lrate=0.500, error=6.042
# > epoch=6699, lrate=0.500, error=6.041
# > epoch=6799, lrate=0.500, error=6.041
# > epoch=6899, lrate=0.500, error=6.040
# > epoch=6999, lrate=0.500, error=6.039
# > epoch=7099, lrate=0.500, error=6.039
# > epoch=7199, lrate=0.500, error=6.038
# > epoch=7299, lrate=0.500, error=6.038
# > epoch=7399, lrate=0.500, error=6.037
# > epoch=7499, lrate=0.500, error=6.036
# > epoch=7599, lrate=0.500, error=6.036
# > epoch=7699, lrate=0.500, error=6.035
# > epoch=7799, lrate=0.500, error=6.035
# > epoch=7899, lrate=0.500, error=6.034
# > epoch=7999, lrate=0.500, error=6.034
# > epoch=8099, lrate=0.500, error=6.034
# > epoch=8199, lrate=0.500, error=6.033
# > epoch=8299, lrate=0.500, error=6.033
# > epoch=8399, lrate=0.500, error=6.032
# > epoch=8499, lrate=0.500, error=6.032
# > epoch=8599, lrate=0.500, error=6.031
# > epoch=8699, lrate=0.500, error=6.031
# > epoch=8799, lrate=0.500, error=6.031
# > epoch=8899, lrate=0.500, error=6.030
# > epoch=8999, lrate=0.500, error=6.030
# > epoch=9099, lrate=0.500, error=6.029
# > epoch=9199, lrate=0.500, error=6.029
# > epoch=9299, lrate=0.500, error=6.029
# > epoch=9399, lrate=0.500, error=6.028
# > epoch=9499, lrate=0.500, error=6.028
# > epoch=9599, lrate=0.500, error=6.028
# > epoch=9699, lrate=0.500, error=6.027
# > epoch=9799, lrate=0.500, error=6.027
# > epoch=9899, lrate=0.500, error=6.027
# > epoch=9999, lrate=0.500, error=6.027
# time = 104.57996940000157
# 100 %

# %% [markdown]
# # Testing begins here for 2 bit output

# %%
with open('../Project/data/languageDecryptor.json') as data_file:
    temp1 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp2 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp3 = json.load(data_file)

# %%
for i in range(100):
    temp1[i][-1] = temp1[i][-1][:2]
    temp2[i][-1] = temp2[i][-1][2:4]
    temp3[i][-1] = temp3[i][-1][4:6]

# %%
layers_list = list()
for i in range(3):
    l = list()
    l.append([int(i) for i in input().split(" ")])
    l.append(float(input())/2)
    l.append(int(input())*10000)
    layers_list.append(l)
# Out:
# 8 9 7 2
# 2
# 1
# 8 9 7 2
# 2
# 3
# 8 10 6 2
# 2
# 3

# %%
count = 1
for i in layers_list:
    seed(1)
    network = initialize_network(i[0])
    n_inputs = len(temp3) - 1
    n_outputs = len(temp3[-1])
    f=open('../Test_images/decryptor_design_2bit_nw3.txt','a')
    s = "{})\n".format(c)
    f.write(s)
    s = "Test name : decryptor_{}_test\n".format(count)
    f.write(s)
    s = "Layers : " + str(i[0]) +"\n"
    f.write(s)
    f.close()
    start = timeit.default_timer()
    train_network(network, temp3, i[1], i[2], n_outputs, count)
    stop = timeit.default_timer()
    print("time = {}".format(stop - start))
    c = 0
    new_dataset = list()
    for b in dataset:
        k = predict(network,b,0)
        s = ""
        k = list(map(str,k))
        k = s.join(k)
        j = b[-1]
        s = ""
        j= list(map(str,j))
        j = s.join(j)
        if(k != j):
            new_dataset.append(b)
            c += 1
    f=open('../Test_images/decryptor_design_2bit_nw3.txt','a')

    f.write("Time : {}".format(stop - start))
    f.close()
    print(str(c)+" %")
    count += 1
# Out:
# > epoch=99, lrate=1.000, error=47.782
# > epoch=199, lrate=1.000, error=29.489
# > epoch=299, lrate=1.000, error=17.290
# > epoch=399, lrate=1.000, error=11.760
# > epoch=499, lrate=1.000, error=7.653
# > epoch=599, lrate=1.000, error=7.402
# > epoch=699, lrate=1.000, error=6.179
# > epoch=799, lrate=1.000, error=5.963
# > epoch=899, lrate=1.000, error=5.884
# > epoch=999, lrate=1.000, error=5.847
# > epoch=1099, lrate=1.000, error=5.824
# > epoch=1199, lrate=1.000, error=5.808
# > epoch=1299, lrate=1.000, error=5.797
# > epoch=1399, lrate=1.000, error=5.788
# > epoch=1499, lrate=1.000, error=5.781
# > epoch=1599, lrate=1.000, error=5.776
# > epoch=1699, lrate=1.000, error=5.772
# > epoch=1799, lrate=1.000, error=5.768
# > epoch=1899, lrate=1.000, error=5.765
# > epoch=1999, lrate=1.000, error=5.762
# > epoch=2099, lrate=1.000, error=5.760
# > epoch=2199, lrate=1.000, error=5.758
# > epoch=2299, lrate=1.000, error=5.756
# > epoch=2399, lrate=1.000, error=5.755
# > epoch=2499, lrate=1.000, error=5.753
# > epoch=2599, lrate=1.000, error=5.752
# > epoch=2699, lrate=1.000, error=5.751
# > epoch=2799, lrate=1.000, error=5.750
# > epoch=2899, lrate=1.000, error=5.749
# > epoch=2999, lrate=1.000, error=5.748
# > epoch=3099, lrate=1.000, error=5.748
# > epoch=3199, lrate=1.000, error=5.747
# > epoch=3299, lrate=1.000, error=5.746
# > epoch=3399, lrate=1.000, error=5.746
# > epoch=3499, lrate=1.000, error=5.745
# > epoch=3599, lrate=1.000, error=5.745
# > epoch=3699, lrate=1.000, error=5.744
# > epoch=3799, lrate=1.000, error=5.744
# > epoch=3899, lrate=1.000, error=5.743
# > epoch=3999, lrate=1.000, error=5.743
# > epoch=4099, lrate=1.000, error=5.742
# > epoch=4199, lrate=1.000, error=5.742
# > epoch=4299, lrate=1.000, error=5.742
# > epoch=4399, lrate=1.000, error=5.741
# > epoch=4499, lrate=1.000, error=5.741
# > epoch=4599, lrate=1.000, error=5.741
# > epoch=4699, lrate=1.000, error=5.741
# > epoch=4799, lrate=1.000, error=5.740
# > epoch=4899, lrate=1.000, error=5.740
# > epoch=4999, lrate=1.000, error=5.740
# > epoch=5099, lrate=1.000, error=5.739
# > epoch=5199, lrate=1.000, error=5.739
# > epoch=5299, lrate=1.000, error=5.739
# > epoch=5399, lrate=1.000, error=5.739
# > epoch=5499, lrate=1.000, error=5.739
# > epoch=5599, lrate=1.000, error=5.738
# > epoch=5699, lrate=1.000, error=5.738
# > epoch=5799, lrate=1.000, error=5.738
# > epoch=5899, lrate=1.000, error=5.738
# > epoch=5999, lrate=1.000, error=5.738
# > epoch=6099, lrate=1.000, error=5.737
# > epoch=6199, lrate=1.000, error=5.737
# > epoch=6299, lrate=1.000, error=5.737
# > epoch=6399, lrate=1.000, error=5.736
# > epoch=6499, lrate=1.000, error=5.736
# > epoch=6599, lrate=1.000, error=5.733
# > epoch=6699, lrate=1.000, error=5.693
# > epoch=6799, lrate=1.000, error=5.596
# > epoch=6899, lrate=1.000, error=5.589
# > epoch=6999, lrate=1.000, error=5.586
# > epoch=7099, lrate=1.000, error=5.584
# > epoch=7199, lrate=1.000, error=5.582
# > epoch=7299, lrate=1.000, error=5.581
# > epoch=7399, lrate=1.000, error=5.580
# > epoch=7499, lrate=1.000, error=5.579
# > epoch=7599, lrate=1.000, error=5.579
# > epoch=7699, lrate=1.000, error=5.578
# > epoch=7799, lrate=1.000, error=5.577
# > epoch=7899, lrate=1.000, error=5.577
# > epoch=7999, lrate=1.000, error=5.576
# > epoch=8099, lrate=1.000, error=5.575
# > epoch=8199, lrate=1.000, error=5.574
# > epoch=8299, lrate=1.000, error=5.571
# > epoch=8399, lrate=1.000, error=5.560
# > epoch=8499, lrate=1.000, error=5.525
# > epoch=8599, lrate=1.000, error=5.446
# > epoch=8699, lrate=1.000, error=5.275
# > epoch=8799, lrate=1.000, error=5.058
# > epoch=8899, lrate=1.000, error=5.038
# > epoch=8999, lrate=1.000, error=5.029
# > epoch=9099, lrate=1.000, error=5.025
# > epoch=9199, lrate=1.000, error=5.022
# > epoch=9299, lrate=1.000, error=5.019
# > epoch=9399, lrate=1.000, error=5.018
# > epoch=9499, lrate=1.000, error=5.016
# > epoch=9599, lrate=1.000, error=5.015
# > epoch=9699, lrate=1.000, error=5.014
# > epoch=9799, lrate=1.000, error=5.013
# > epoch=9899, lrate=1.000, error=5.013
# > epoch=9999, lrate=1.000, error=5.012
# time = 98.12906700099848
# 100 %
# > epoch=99, lrate=1.000, error=47.782
# > epoch=199, lrate=1.000, error=29.489
# > epoch=299, lrate=1.000, error=17.290
# > epoch=399, lrate=1.000, error=11.760
# > epoch=499, lrate=1.000, error=7.653
# > epoch=599, lrate=1.000, error=7.402
# > epoch=699, lrate=1.000, error=6.179
# > epoch=799, lrate=1.000, error=5.963
# > epoch=899, lrate=1.000, error=5.884
# > epoch=999, lrate=1.000, error=5.847
# > epoch=1099, lrate=1.000, error=5.824
# > epoch=1199, lrate=1.000, error=5.808
# > epoch=1299, lrate=1.000, error=5.797
# > epoch=1399, lrate=1.000, error=5.788
# > epoch=1499, lrate=1.000, error=5.781
# > epoch=1599, lrate=1.000, error=5.776
# > epoch=1699, lrate=1.000, error=5.772
# > epoch=1799, lrate=1.000, error=5.768
# > epoch=1899, lrate=1.000, error=5.765
# > epoch=1999, lrate=1.000, error=5.762
# > epoch=2099, lrate=1.000, error=5.760
# > epoch=2199, lrate=1.000, error=5.758
# > epoch=2299, lrate=1.000, error=5.756
# > epoch=2399, lrate=1.000, error=5.755
# > epoch=2499, lrate=1.000, error=5.753
# > epoch=2599, lrate=1.000, error=5.752
# > epoch=2699, lrate=1.000, error=5.751
# > epoch=2799, lrate=1.000, error=5.750
# > epoch=2899, lrate=1.000, error=5.749
# > epoch=2999, lrate=1.000, error=5.748
# > epoch=3099, lrate=1.000, error=5.748
# > epoch=3199, lrate=1.000, error=5.747
# > epoch=3299, lrate=1.000, error=5.746
# > epoch=3399, lrate=1.000, error=5.746
# > epoch=3499, lrate=1.000, error=5.745
# > epoch=3599, lrate=1.000, error=5.745
# > epoch=3699, lrate=1.000, error=5.744
# > epoch=3799, lrate=1.000, error=5.744
# > epoch=3899, lrate=1.000, error=5.743
# > epoch=3999, lrate=1.000, error=5.743
# > epoch=4099, lrate=1.000, error=5.742
# > epoch=4199, lrate=1.000, error=5.742
# > epoch=4299, lrate=1.000, error=5.742
# > epoch=4399, lrate=1.000, error=5.741
# > epoch=4499, lrate=1.000, error=5.741
# > epoch=4599, lrate=1.000, error=5.741
# > epoch=4699, lrate=1.000, error=5.741
# > epoch=4799, lrate=1.000, error=5.740
# > epoch=4899, lrate=1.000, error=5.740
# > epoch=4999, lrate=1.000, error=5.740
# > epoch=5099, lrate=1.000, error=5.739
# > epoch=5199, lrate=1.000, error=5.739
# > epoch=5299, lrate=1.000, error=5.739
# > epoch=5399, lrate=1.000, error=5.739
# > epoch=5499, lrate=1.000, error=5.739
# > epoch=5599, lrate=1.000, error=5.738
# > epoch=5699, lrate=1.000, error=5.738
# > epoch=5799, lrate=1.000, error=5.738
# > epoch=5899, lrate=1.000, error=5.738
# > epoch=5999, lrate=1.000, error=5.738
# > epoch=6099, lrate=1.000, error=5.737
# > epoch=6199, lrate=1.000, error=5.737
# > epoch=6299, lrate=1.000, error=5.737
# > epoch=6399, lrate=1.000, error=5.736
# > epoch=6499, lrate=1.000, error=5.736
# > epoch=6599, lrate=1.000, error=5.733
# > epoch=6699, lrate=1.000, error=5.693
# > epoch=6799, lrate=1.000, error=5.596
# > epoch=6899, lrate=1.000, error=5.589
# > epoch=6999, lrate=1.000, error=5.586
# > epoch=7099, lrate=1.000, error=5.584
# > epoch=7199, lrate=1.000, error=5.582
# > epoch=7299, lrate=1.000, error=5.581
# > epoch=7399, lrate=1.000, error=5.580
# > epoch=7499, lrate=1.000, error=5.579
# > epoch=7599, lrate=1.000, error=5.579
# > epoch=7699, lrate=1.000, error=5.578
# > epoch=7799, lrate=1.000, error=5.577
# > epoch=7899, lrate=1.000, error=5.577
# > epoch=7999, lrate=1.000, error=5.576
# > epoch=8099, lrate=1.000, error=5.575
# > epoch=8199, lrate=1.000, error=5.574
# > epoch=8299, lrate=1.000, error=5.571
# > epoch=8399, lrate=1.000, error=5.560
# > epoch=8499, lrate=1.000, error=5.525
# > epoch=8599, lrate=1.000, error=5.446
# > epoch=8699, lrate=1.000, error=5.275
# > epoch=8799, lrate=1.000, error=5.058
# > epoch=8899, lrate=1.000, error=5.038
# > epoch=8999, lrate=1.000, error=5.029
# > epoch=9099, lrate=1.000, error=5.025
# > epoch=9199, lrate=1.000, error=5.022
# > epoch=9299, lrate=1.000, error=5.019
# > epoch=9399, lrate=1.000, error=5.018
# > epoch=9499, lrate=1.000, error=5.016
# > epoch=9599, lrate=1.000, error=5.015
# > epoch=9699, lrate=1.000, error=5.014
# > epoch=9799, lrate=1.000, error=5.013
# > epoch=9899, lrate=1.000, error=5.013
# > epoch=9999, lrate=1.000, error=5.012
# > epoch=10099, lrate=1.000, error=5.011
# > epoch=10199, lrate=1.000, error=5.011
# > epoch=10299, lrate=1.000, error=5.010
# > epoch=10399, lrate=1.000, error=5.010
# > epoch=10499, lrate=1.000, error=5.010
# > epoch=10599, lrate=1.000, error=5.009
# > epoch=10699, lrate=1.000, error=5.009
# > epoch=10799, lrate=1.000, error=5.009
# > epoch=10899, lrate=1.000, error=5.008
# > epoch=10999, lrate=1.000, error=5.008
# > epoch=11099, lrate=1.000, error=5.008
# > epoch=11199, lrate=1.000, error=5.008
# > epoch=11299, lrate=1.000, error=5.007
# > epoch=11399, lrate=1.000, error=5.007
# > epoch=11499, lrate=1.000, error=5.007
# > epoch=11599, lrate=1.000, error=5.007
# > epoch=11699, lrate=1.000, error=5.007
# > epoch=11799, lrate=1.000, error=5.007
# > epoch=11899, lrate=1.000, error=5.006
# > epoch=11999, lrate=1.000, error=5.006
# > epoch=12099, lrate=1.000, error=5.006
# > epoch=12199, lrate=1.000, error=5.006
# > epoch=12299, lrate=1.000, error=5.006
# > epoch=12399, lrate=1.000, error=5.006
# > epoch=12499, lrate=1.000, error=5.006
# > epoch=12599, lrate=1.000, error=5.006
# > epoch=12699, lrate=1.000, error=5.005
# > epoch=12799, lrate=1.000, error=5.005
# > epoch=12899, lrate=1.000, error=5.005
# > epoch=12999, lrate=1.000, error=5.005
# > epoch=13099, lrate=1.000, error=5.005
# > epoch=13199, lrate=1.000, error=5.005
# > epoch=13299, lrate=1.000, error=5.005
# > epoch=13399, lrate=1.000, error=5.005
# > epoch=13499, lrate=1.000, error=5.005
# > epoch=13599, lrate=1.000, error=5.005
# > epoch=13699, lrate=1.000, error=5.005
# > epoch=13799, lrate=1.000, error=5.005
# > epoch=13899, lrate=1.000, error=5.005
# > epoch=13999, lrate=1.000, error=5.004
# > epoch=14099, lrate=1.000, error=5.004
# > epoch=14199, lrate=1.000, error=5.004
# > epoch=14299, lrate=1.000, error=5.004
# > epoch=14399, lrate=1.000, error=5.004
# > epoch=14499, lrate=1.000, error=5.004
# > epoch=14599, lrate=1.000, error=5.004
# > epoch=14699, lrate=1.000, error=5.004
# > epoch=14799, lrate=1.000, error=5.004
# > epoch=14899, lrate=1.000, error=5.004
# > epoch=14999, lrate=1.000, error=5.004
# > epoch=15099, lrate=1.000, error=5.004
# > epoch=15199, lrate=1.000, error=5.004
# > epoch=15299, lrate=1.000, error=5.004
# > epoch=15399, lrate=1.000, error=5.004
# > epoch=15499, lrate=1.000, error=5.004
# > epoch=15599, lrate=1.000, error=5.004
# > epoch=15699, lrate=1.000, error=5.004
# > epoch=15799, lrate=1.000, error=5.004
# > epoch=15899, lrate=1.000, error=5.004
# > epoch=15999, lrate=1.000, error=5.003
# > epoch=16099, lrate=1.000, error=5.003
# > epoch=16199, lrate=1.000, error=5.003
# > epoch=16299, lrate=1.000, error=5.003
# > epoch=16399, lrate=1.000, error=5.003
# > epoch=16499, lrate=1.000, error=5.003
# > epoch=16599, lrate=1.000, error=5.003
# > epoch=16699, lrate=1.000, error=5.003
# > epoch=16799, lrate=1.000, error=5.003
# > epoch=16899, lrate=1.000, error=5.003
# > epoch=16999, lrate=1.000, error=5.003
# > epoch=17099, lrate=1.000, error=5.003
# > epoch=17199, lrate=1.000, error=5.003
# > epoch=17299, lrate=1.000, error=5.003
# > epoch=17399, lrate=1.000, error=5.003
# > epoch=17499, lrate=1.000, error=5.003
# > epoch=17599, lrate=1.000, error=5.003
# > epoch=17699, lrate=1.000, error=5.003
# > epoch=17799, lrate=1.000, error=5.003
# > epoch=17899, lrate=1.000, error=5.003
# > epoch=17999, lrate=1.000, error=5.003
# > epoch=18099, lrate=1.000, error=5.003
# > epoch=18199, lrate=1.000, error=5.003
# > epoch=18299, lrate=1.000, error=5.003
# > epoch=18399, lrate=1.000, error=5.003
# > epoch=18499, lrate=1.000, error=5.003
# > epoch=18599, lrate=1.000, error=5.003
# > epoch=18699, lrate=1.000, error=5.003
# > epoch=18799, lrate=1.000, error=5.003
# > epoch=18899, lrate=1.000, error=5.003
# > epoch=18999, lrate=1.000, error=5.003
# > epoch=19099, lrate=1.000, error=5.003
# > epoch=19199, lrate=1.000, error=5.003
# > epoch=19299, lrate=1.000, error=5.003
# > epoch=19399, lrate=1.000, error=5.003
# > epoch=19499, lrate=1.000, error=5.003
# > epoch=19599, lrate=1.000, error=5.003
# > epoch=19699, lrate=1.000, error=5.002
# > epoch=19799, lrate=1.000, error=5.002
# > epoch=19899, lrate=1.000, error=5.002
# > epoch=19999, lrate=1.000, error=5.002
# > epoch=20099, lrate=1.000, error=5.002
# > epoch=20199, lrate=1.000, error=5.002
# > epoch=20299, lrate=1.000, error=5.002
# > epoch=20399, lrate=1.000, error=5.002
# > epoch=20499, lrate=1.000, error=5.002
# > epoch=20599, lrate=1.000, error=5.002
# > epoch=20699, lrate=1.000, error=5.002
# > epoch=20799, lrate=1.000, error=5.002
# > epoch=20899, lrate=1.000, error=5.002
# > epoch=20999, lrate=1.000, error=5.002
# > epoch=21099, lrate=1.000, error=5.002
# > epoch=21199, lrate=1.000, error=5.002
# > epoch=21299, lrate=1.000, error=5.002
# > epoch=21399, lrate=1.000, error=5.002
# > epoch=21499, lrate=1.000, error=5.002
# > epoch=21599, lrate=1.000, error=5.002
# > epoch=21699, lrate=1.000, error=5.002
# > epoch=21799, lrate=1.000, error=5.002
# > epoch=21899, lrate=1.000, error=5.002
# > epoch=21999, lrate=1.000, error=5.002
# > epoch=22099, lrate=1.000, error=5.002
# > epoch=22199, lrate=1.000, error=5.002
# > epoch=22299, lrate=1.000, error=5.002
# > epoch=22399, lrate=1.000, error=5.002
# > epoch=22499, lrate=1.000, error=5.002
# > epoch=22599, lrate=1.000, error=5.002
# > epoch=22699, lrate=1.000, error=5.002
# > epoch=22799, lrate=1.000, error=5.002
# > epoch=22899, lrate=1.000, error=5.002
# > epoch=22999, lrate=1.000, error=5.002
# > epoch=23099, lrate=1.000, error=5.002
# > epoch=23199, lrate=1.000, error=5.002
# > epoch=23299, lrate=1.000, error=5.002
# > epoch=23399, lrate=1.000, error=5.002
# > epoch=23499, lrate=1.000, error=5.002
# > epoch=23599, lrate=1.000, error=5.002
# > epoch=23699, lrate=1.000, error=5.002
# > epoch=23799, lrate=1.000, error=5.002
# > epoch=23899, lrate=1.000, error=5.002
# > epoch=23999, lrate=1.000, error=5.002
# > epoch=24099, lrate=1.000, error=5.002
# > epoch=24199, lrate=1.000, error=5.002
# > epoch=24299, lrate=1.000, error=5.002
# > epoch=24399, lrate=1.000, error=5.002
# > epoch=24499, lrate=1.000, error=5.002
# > epoch=24599, lrate=1.000, error=5.002
# > epoch=24699, lrate=1.000, error=5.002
# > epoch=24799, lrate=1.000, error=5.002
# > epoch=24899, lrate=1.000, error=5.002
# > epoch=24999, lrate=1.000, error=5.002
# > epoch=25099, lrate=1.000, error=5.002
# > epoch=25199, lrate=1.000, error=5.002
# > epoch=25299, lrate=1.000, error=5.002
# > epoch=25399, lrate=1.000, error=5.002
# > epoch=25499, lrate=1.000, error=5.002
# > epoch=25599, lrate=1.000, error=5.002
# > epoch=25699, lrate=1.000, error=5.002
# > epoch=25799, lrate=1.000, error=5.002
# > epoch=25899, lrate=1.000, error=5.002
# > epoch=25999, lrate=1.000, error=5.002
# > epoch=26099, lrate=1.000, error=5.002
# > epoch=26199, lrate=1.000, error=5.002
# > epoch=26299, lrate=1.000, error=5.002
# > epoch=26399, lrate=1.000, error=5.002
# > epoch=26499, lrate=1.000, error=5.002
# > epoch=26599, lrate=1.000, error=5.002
# > epoch=26699, lrate=1.000, error=5.002
# > epoch=26799, lrate=1.000, error=5.002
# > epoch=26899, lrate=1.000, error=5.002
# > epoch=26999, lrate=1.000, error=5.002
# > epoch=27099, lrate=1.000, error=5.002
# > epoch=27199, lrate=1.000, error=5.002
# > epoch=27299, lrate=1.000, error=5.002
# > epoch=27399, lrate=1.000, error=5.002
# > epoch=27499, lrate=1.000, error=5.002
# > epoch=27599, lrate=1.000, error=5.002
# > epoch=27699, lrate=1.000, error=5.002
# > epoch=27799, lrate=1.000, error=5.002
# > epoch=27899, lrate=1.000, error=5.002
# > epoch=27999, lrate=1.000, error=5.002
# > epoch=28099, lrate=1.000, error=5.002
# > epoch=28199, lrate=1.000, error=5.002
# > epoch=28299, lrate=1.000, error=5.002
# > epoch=28399, lrate=1.000, error=5.002
# > epoch=28499, lrate=1.000, error=5.002
# > epoch=28599, lrate=1.000, error=5.002
# > epoch=28699, lrate=1.000, error=5.002
# > epoch=28799, lrate=1.000, error=5.001
# > epoch=28899, lrate=1.000, error=5.001
# > epoch=28999, lrate=1.000, error=5.001
# > epoch=29099, lrate=1.000, error=5.001
# > epoch=29199, lrate=1.000, error=5.001
# > epoch=29299, lrate=1.000, error=5.001
# > epoch=29399, lrate=1.000, error=5.001
# > epoch=29499, lrate=1.000, error=5.001
# > epoch=29599, lrate=1.000, error=5.001
# > epoch=29699, lrate=1.000, error=5.001
# > epoch=29799, lrate=1.000, error=5.001
# > epoch=29899, lrate=1.000, error=5.001
# > epoch=29999, lrate=1.000, error=5.001
# time = 293.78510403700056
# 100 %
# > epoch=99, lrate=1.000, error=49.038
# > epoch=199, lrate=1.000, error=33.575
# > epoch=299, lrate=1.000, error=17.403
# > epoch=399, lrate=1.000, error=14.431
# > epoch=499, lrate=1.000, error=10.991
# > epoch=599, lrate=1.000, error=9.953
# > epoch=699, lrate=1.000, error=9.811
# > epoch=799, lrate=1.000, error=9.184
# > epoch=899, lrate=1.000, error=8.126
# > epoch=999, lrate=1.000, error=8.068
# > epoch=1099, lrate=1.000, error=8.049
# > epoch=1199, lrate=1.000, error=8.038
# > epoch=1299, lrate=1.000, error=8.032
# > epoch=1399, lrate=1.000, error=8.027
# > epoch=1499, lrate=1.000, error=8.024
# > epoch=1599, lrate=1.000, error=8.021
# > epoch=1699, lrate=1.000, error=8.019
# > epoch=1799, lrate=1.000, error=8.017
# > epoch=1899, lrate=1.000, error=8.016
# > epoch=1999, lrate=1.000, error=8.015
# > epoch=2099, lrate=1.000, error=8.014
# > epoch=2199, lrate=1.000, error=8.013
# > epoch=2299, lrate=1.000, error=8.012
# > epoch=2399, lrate=1.000, error=8.011
# > epoch=2499, lrate=1.000, error=8.011
# > epoch=2599, lrate=1.000, error=8.010
# > epoch=2699, lrate=1.000, error=8.010
# > epoch=2799, lrate=1.000, error=8.009
# > epoch=2899, lrate=1.000, error=8.009
# > epoch=2999, lrate=1.000, error=8.008
# > epoch=3099, lrate=1.000, error=8.008
# > epoch=3199, lrate=1.000, error=8.008
# > epoch=3299, lrate=1.000, error=8.007
# > epoch=3399, lrate=1.000, error=8.007
# > epoch=3499, lrate=1.000, error=8.007
# > epoch=3599, lrate=1.000, error=8.007
# > epoch=3699, lrate=1.000, error=8.007
# > epoch=3799, lrate=1.000, error=8.006
# > epoch=3899, lrate=1.000, error=8.006
# > epoch=3999, lrate=1.000, error=8.006
# > epoch=4099, lrate=1.000, error=8.006
# > epoch=4199, lrate=1.000, error=8.006
# > epoch=4299, lrate=1.000, error=8.005
# > epoch=4399, lrate=1.000, error=8.005
# > epoch=4499, lrate=1.000, error=8.005
# > epoch=4599, lrate=1.000, error=8.005
# > epoch=4699, lrate=1.000, error=8.005
# > epoch=4799, lrate=1.000, error=8.005
# > epoch=4899, lrate=1.000, error=8.005
# > epoch=4999, lrate=1.000, error=8.005
# > epoch=5099, lrate=1.000, error=8.004
# > epoch=5199, lrate=1.000, error=8.004
# > epoch=5299, lrate=1.000, error=8.004
# > epoch=5399, lrate=1.000, error=8.004
# > epoch=5499, lrate=1.000, error=8.004
# > epoch=5599, lrate=1.000, error=8.004
# > epoch=5699, lrate=1.000, error=8.004
# > epoch=5799, lrate=1.000, error=8.004
# > epoch=5899, lrate=1.000, error=8.004
# > epoch=5999, lrate=1.000, error=8.004
# > epoch=6099, lrate=1.000, error=8.004
# > epoch=6199, lrate=1.000, error=8.004
# > epoch=6299, lrate=1.000, error=8.003
# > epoch=6399, lrate=1.000, error=8.003
# > epoch=6499, lrate=1.000, error=8.003
# > epoch=6599, lrate=1.000, error=8.003
# > epoch=6699, lrate=1.000, error=8.003
# > epoch=6799, lrate=1.000, error=8.003
# > epoch=6899, lrate=1.000, error=8.003
# > epoch=6999, lrate=1.000, error=8.003
# > epoch=7099, lrate=1.000, error=8.003
# > epoch=7199, lrate=1.000, error=8.003
# > epoch=7299, lrate=1.000, error=8.003
# > epoch=7399, lrate=1.000, error=8.003
# > epoch=7499, lrate=1.000, error=8.003
# > epoch=7599, lrate=1.000, error=8.003
# > epoch=7699, lrate=1.000, error=8.003
# > epoch=7799, lrate=1.000, error=8.003
# > epoch=7899, lrate=1.000, error=8.003
# > epoch=7999, lrate=1.000, error=8.003
# > epoch=8099, lrate=1.000, error=8.003
# > epoch=8199, lrate=1.000, error=8.003
# > epoch=8299, lrate=1.000, error=8.003
# > epoch=8399, lrate=1.000, error=8.003
# > epoch=8499, lrate=1.000, error=8.002
# > epoch=8599, lrate=1.000, error=8.002
# > epoch=8699, lrate=1.000, error=8.002
# > epoch=8799, lrate=1.000, error=8.002
# > epoch=8899, lrate=1.000, error=8.002
# > epoch=8999, lrate=1.000, error=8.002
# > epoch=9099, lrate=1.000, error=8.002
# > epoch=9199, lrate=1.000, error=8.002
# > epoch=9299, lrate=1.000, error=8.002
# > epoch=9399, lrate=1.000, error=8.002
# > epoch=9499, lrate=1.000, error=8.002
# > epoch=9599, lrate=1.000, error=8.002
# > epoch=9699, lrate=1.000, error=8.002
# > epoch=9799, lrate=1.000, error=8.002
# > epoch=9899, lrate=1.000, error=8.002
# > epoch=9999, lrate=1.000, error=8.002
# > epoch=10099, lrate=1.000, error=8.002
# > epoch=10199, lrate=1.000, error=8.002
# > epoch=10299, lrate=1.000, error=8.002
# > epoch=10399, lrate=1.000, error=8.002
# > epoch=10499, lrate=1.000, error=8.002
# > epoch=10599, lrate=1.000, error=8.002
# > epoch=10699, lrate=1.000, error=8.002
# > epoch=10799, lrate=1.000, error=8.002
# > epoch=10899, lrate=1.000, error=8.002
# > epoch=10999, lrate=1.000, error=8.002
# > epoch=11099, lrate=1.000, error=8.002
# > epoch=11199, lrate=1.000, error=8.002
# > epoch=11299, lrate=1.000, error=8.002
# > epoch=11399, lrate=1.000, error=8.002
# > epoch=11499, lrate=1.000, error=8.002
# > epoch=11599, lrate=1.000, error=8.002
# > epoch=11699, lrate=1.000, error=8.002
# > epoch=11799, lrate=1.000, error=8.002
# > epoch=11899, lrate=1.000, error=8.002
# > epoch=11999, lrate=1.000, error=8.002
# > epoch=12099, lrate=1.000, error=8.002
# > epoch=12199, lrate=1.000, error=8.002
# > epoch=12299, lrate=1.000, error=8.002
# > epoch=12399, lrate=1.000, error=8.002
# > epoch=12499, lrate=1.000, error=8.002
# > epoch=12599, lrate=1.000, error=8.002
# > epoch=12699, lrate=1.000, error=8.002
# > epoch=12799, lrate=1.000, error=8.002
# > epoch=12899, lrate=1.000, error=8.002
# > epoch=12999, lrate=1.000, error=8.002
# > epoch=13099, lrate=1.000, error=8.002
# > epoch=13199, lrate=1.000, error=8.002
# > epoch=13299, lrate=1.000, error=8.001
# > epoch=13399, lrate=1.000, error=8.001
# > epoch=13499, lrate=1.000, error=8.001
# > epoch=13599, lrate=1.000, error=8.001
# > epoch=13699, lrate=1.000, error=8.001
# > epoch=13799, lrate=1.000, error=8.001
# > epoch=13899, lrate=1.000, error=8.001
# > epoch=13999, lrate=1.000, error=8.001
# > epoch=14099, lrate=1.000, error=8.001
# > epoch=14199, lrate=1.000, error=8.001
# > epoch=14299, lrate=1.000, error=8.001
# > epoch=14399, lrate=1.000, error=8.001
# > epoch=14499, lrate=1.000, error=8.001
# > epoch=14599, lrate=1.000, error=8.001
# > epoch=14699, lrate=1.000, error=8.001
# > epoch=14799, lrate=1.000, error=8.001
# > epoch=14899, lrate=1.000, error=8.001
# > epoch=14999, lrate=1.000, error=8.001
# > epoch=15099, lrate=1.000, error=8.001
# > epoch=15199, lrate=1.000, error=8.001
# > epoch=15299, lrate=1.000, error=8.001
# > epoch=15399, lrate=1.000, error=8.001
# > epoch=15499, lrate=1.000, error=8.001
# > epoch=15599, lrate=1.000, error=8.001
# > epoch=15699, lrate=1.000, error=8.001
# > epoch=15799, lrate=1.000, error=8.001
# > epoch=15899, lrate=1.000, error=8.001
# > epoch=15999, lrate=1.000, error=8.001
# > epoch=16099, lrate=1.000, error=8.001
# > epoch=16199, lrate=1.000, error=8.001
# > epoch=16299, lrate=1.000, error=8.001
# > epoch=16399, lrate=1.000, error=8.001
# > epoch=16499, lrate=1.000, error=8.001
# > epoch=16599, lrate=1.000, error=8.001
# > epoch=16699, lrate=1.000, error=8.001
# > epoch=16799, lrate=1.000, error=8.001
# > epoch=16899, lrate=1.000, error=8.001
# > epoch=16999, lrate=1.000, error=8.001
# > epoch=17099, lrate=1.000, error=8.001
# > epoch=17199, lrate=1.000, error=8.001
# > epoch=17299, lrate=1.000, error=8.001
# > epoch=17399, lrate=1.000, error=8.001
# > epoch=17499, lrate=1.000, error=8.001
# > epoch=17599, lrate=1.000, error=8.001
# > epoch=17699, lrate=1.000, error=8.001
# > epoch=17799, lrate=1.000, error=8.001
# > epoch=17899, lrate=1.000, error=8.001
# > epoch=17999, lrate=1.000, error=8.001
# > epoch=18099, lrate=1.000, error=8.001
# > epoch=18199, lrate=1.000, error=8.001
# > epoch=18299, lrate=1.000, error=8.001
# > epoch=18399, lrate=1.000, error=8.001
# > epoch=18499, lrate=1.000, error=8.001
# > epoch=18599, lrate=1.000, error=8.001
# > epoch=18699, lrate=1.000, error=8.001
# > epoch=18799, lrate=1.000, error=8.001
# > epoch=18899, lrate=1.000, error=8.001
# > epoch=18999, lrate=1.000, error=8.001
# > epoch=19099, lrate=1.000, error=8.001
# > epoch=19199, lrate=1.000, error=8.001
# > epoch=19299, lrate=1.000, error=8.001
# > epoch=19399, lrate=1.000, error=8.001
# > epoch=19499, lrate=1.000, error=8.001
# > epoch=19599, lrate=1.000, error=8.001
# > epoch=19699, lrate=1.000, error=8.001
# > epoch=19799, lrate=1.000, error=8.001
# > epoch=19899, lrate=1.000, error=8.001
# > epoch=19999, lrate=1.000, error=8.001
# > epoch=20099, lrate=1.000, error=8.001
# > epoch=20199, lrate=1.000, error=8.001
# > epoch=20299, lrate=1.000, error=8.001
# > epoch=20399, lrate=1.000, error=8.001
# > epoch=20499, lrate=1.000, error=8.001
# > epoch=20599, lrate=1.000, error=8.001
# > epoch=20699, lrate=1.000, error=8.001
# > epoch=20799, lrate=1.000, error=8.001
# > epoch=20899, lrate=1.000, error=8.001
# > epoch=20999, lrate=1.000, error=8.001
# > epoch=21099, lrate=1.000, error=8.001
# > epoch=21199, lrate=1.000, error=8.001
# > epoch=21299, lrate=1.000, error=8.001
# > epoch=21399, lrate=1.000, error=8.001
# > epoch=21499, lrate=1.000, error=8.001
# > epoch=21599, lrate=1.000, error=8.001
# > epoch=21699, lrate=1.000, error=8.001
# > epoch=21799, lrate=1.000, error=8.001
# > epoch=21899, lrate=1.000, error=8.001
# > epoch=21999, lrate=1.000, error=8.001
# > epoch=22099, lrate=1.000, error=8.001
# > epoch=22199, lrate=1.000, error=8.001
# > epoch=22299, lrate=1.000, error=8.001
# > epoch=22399, lrate=1.000, error=8.001
# > epoch=22499, lrate=1.000, error=8.001
# > epoch=22599, lrate=1.000, error=8.001
# > epoch=22699, lrate=1.000, error=8.001
# > epoch=22799, lrate=1.000, error=8.001
# > epoch=22899, lrate=1.000, error=8.001
# > epoch=22999, lrate=1.000, error=8.001
# > epoch=23099, lrate=1.000, error=8.001
# > epoch=23199, lrate=1.000, error=8.001
# > epoch=23299, lrate=1.000, error=8.001
# > epoch=23399, lrate=1.000, error=8.001
# > epoch=23499, lrate=1.000, error=8.001
# > epoch=23599, lrate=1.000, error=8.001
# > epoch=23699, lrate=1.000, error=8.001
# > epoch=23799, lrate=1.000, error=8.001
# > epoch=23899, lrate=1.000, error=8.001
# > epoch=23999, lrate=1.000, error=8.001
# > epoch=24099, lrate=1.000, error=8.001
# > epoch=24199, lrate=1.000, error=8.001
# > epoch=24299, lrate=1.000, error=8.001
# > epoch=24399, lrate=1.000, error=8.001
# > epoch=24499, lrate=1.000, error=8.001
# > epoch=24599, lrate=1.000, error=8.001
# > epoch=24699, lrate=1.000, error=8.001
# > epoch=24799, lrate=1.000, error=8.001
# > epoch=24899, lrate=1.000, error=8.001
# > epoch=24999, lrate=1.000, error=8.001
# > epoch=25099, lrate=1.000, error=8.001
# > epoch=25199, lrate=1.000, error=8.001
# > epoch=25299, lrate=1.000, error=8.001
# > epoch=25399, lrate=1.000, error=8.001
# > epoch=25499, lrate=1.000, error=8.001
# > epoch=25599, lrate=1.000, error=8.001
# > epoch=25699, lrate=1.000, error=8.001
# > epoch=25799, lrate=1.000, error=8.001
# > epoch=25899, lrate=1.000, error=8.001
# > epoch=25999, lrate=1.000, error=8.001
# > epoch=26099, lrate=1.000, error=8.001
# > epoch=26199, lrate=1.000, error=8.001
# > epoch=26299, lrate=1.000, error=8.001
# > epoch=26399, lrate=1.000, error=8.001
# > epoch=26499, lrate=1.000, error=8.001
# > epoch=26599, lrate=1.000, error=8.001
# > epoch=26699, lrate=1.000, error=8.001
# > epoch=26799, lrate=1.000, error=8.001
# > epoch=26899, lrate=1.000, error=8.001
# > epoch=26999, lrate=1.000, error=8.001
# > epoch=27099, lrate=1.000, error=8.001
# > epoch=27199, lrate=1.000, error=8.001
# > epoch=27299, lrate=1.000, error=8.001
# > epoch=27399, lrate=1.000, error=8.001
# > epoch=27499, lrate=1.000, error=8.001
# > epoch=27599, lrate=1.000, error=8.001
# > epoch=27699, lrate=1.000, error=8.001
# > epoch=27799, lrate=1.000, error=8.001
# > epoch=27899, lrate=1.000, error=8.001
# > epoch=27999, lrate=1.000, error=8.001
# > epoch=28099, lrate=1.000, error=8.001
# > epoch=28199, lrate=1.000, error=8.001
# > epoch=28299, lrate=1.000, error=8.001
# > epoch=28399, lrate=1.000, error=8.001
# > epoch=28499, lrate=1.000, error=8.001
# > epoch=28599, lrate=1.000, error=8.001
# > epoch=28699, lrate=1.000, error=8.001
# > epoch=28799, lrate=1.000, error=8.001
# > epoch=28899, lrate=1.000, error=8.001
# > epoch=28999, lrate=1.000, error=8.001
# > epoch=29099, lrate=1.000, error=8.001
# > epoch=29199, lrate=1.000, error=8.001
# > epoch=29299, lrate=1.000, error=8.001
# > epoch=29399, lrate=1.000, error=8.001
# > epoch=29499, lrate=1.000, error=8.001
# > epoch=29599, lrate=1.000, error=8.001
# > epoch=29699, lrate=1.000, error=8.001
# > epoch=29799, lrate=1.000, error=8.001
# > epoch=29899, lrate=1.000, error=8.001
# > epoch=29999, lrate=1.000, error=8.001
# time = 296.9883034190061
# 100 %

# %%
with open('../Project/data/languageDecryptor.json') as data_file:
    temp1 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp2 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp3 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp4 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp5 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp6 = json.load(data_file)
    
with open('../Project/data/languageDecryptor.json') as data_file:
    temp7 = json.load(data_file)
